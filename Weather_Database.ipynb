# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import json

# Import dependencies to perform linear regression analysis
from scipy.stats import linregress

# Import the requests library. Import the API key
import requests
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 779

# %%
cities
# Out:
# ['santona',
#  'illoqqortoormiut',
#  'hithadhoo',
#  'chernyshevskiy',
#  'tadine',
#  'praxedis guerrero',
#  'georgetown',
#  'lebu',
#  'thompson',
#  'new norfolk',
#  'avarua',
#  'cockburn town',
#  'jamestown',
#  'barentsburg',
#  'keroka',
#  'barrow',
#  'luderitz',
#  'esperance',
#  'rikitea',
#  'busselton',
#  'acajutla',
#  'broken hill',
#  'saskylakh',
#  'hualmay',
#  'beian',
#  'mar del plata',
#  'punta arenas',
#  'bethel',
#  'bathsheba',
#  'samusu',
#  'erzin',
#  'taolanaro',
#  'guerrero negro',
#  'ushuaia',
#  'juneau',
#  'porto novo',
#  'lhokseumawe',
#  'gwadar',
#  'bredasdorp',
#  'charters towers',
#  'pevek',
#  'sentyabrskiy',
#  'castro',
#  'anadyr',
#  'souillac',
#  'port hedland',
#  'zabol',
#  'kruisfontein',
#  'vaini',
#  'hobart',
#  'vestmanna',
#  'fortuna',
#  'albany',
#  'teya',
#  'olafsvik',
#  'upernavik',
#  'dongying',
#  'mocambique',
#  'kamenka',
#  'tasiilaq',
#  'kaitangata',
#  'williamsport',
#  'cape town',
#  'pandan',
#  'ribnitz-damgarten',
#  'kodiak',
#  'kapaa',
#  'narsaq',
#  'saint-francois',
#  'salalah',
#  'hasaki',
#  'puerto ayora',
#  'kokoda',
#  'giyani',
#  'dikson',
#  'nuuk',
#  'vestmannaeyjar',
#  'coihaique',
#  'sao filipe',
#  'luanda',
#  'port alfred',
#  'faya',
#  'port lincoln',
#  'vilhena',
#  'morgan city',
#  'roma',
#  'carnarvon',
#  'ayan',
#  'korla',
#  'constitucion',
#  'koroni',
#  'laguna',
#  'ponta do sol',
#  'kargopol',
#  'mehndawal',
#  'chumikan',
#  'khatanga',
#  'gamba',
#  'jumla',
#  'san juan',
#  'inta',
#  'ijaki',
#  'ancud',
#  'touros',
#  'rosita',
#  'martapura',
#  'davlekanovo',
#  'jiuquan',
#  'saint george',
#  'kharp',
#  'mys shmidta',
#  'san andres',
#  'nikolskoye',
#  'champerico',
#  'provideniya',
#  'ribeira grande',
#  'atuona',
#  'los llanos de aridane',
#  'tuma',
#  'lata',
#  'qaanaaq',
#  'antofagasta',
#  'mataura',
#  'sechura',
#  'caxito',
#  'huilong',
#  'labuhan',
#  'barkhan',
#  'tual',
#  'chokurdakh',
#  'yellowknife',
#  'joao pinheiro',
#  'tiksi',
#  'lompoc',
#  'burica',
#  'tabou',
#  'bengkulu',
#  'saint-philippe',
#  'cherskiy',
#  'abu samrah',
#  'jimenez',
#  'talnakh',
#  'sinnamary',
#  'bluff',
#  'norman wells',
#  'port hardy',
#  'safaga',
#  'milkovo',
#  'barreiras',
#  'puerto baquerizo moreno',
#  'sitka',
#  'amderma',
#  'inverell',
#  'airai',
#  'lavrentiya',
#  'lagoa',
#  'kenai',
#  'tura',
#  'kosa',
#  'longyearbyen',
#  'cidreira',
#  'matrei',
#  'nalut',
#  'fethiye',
#  'gizo',
#  'severo-kurilsk',
#  'tessalit',
#  'nizhneyansk',
#  'port hawkesbury',
#  'mount gambier',
#  'grand river south east',
#  'vesoul',
#  'salinopolis',
#  'vaitupu',
#  'okhotsk',
#  'port blair',
#  'port elizabeth',
#  'tuktoyaktuk',
#  'mackay',
#  'saint-pierre',
#  'aripuana',
#  'eskasem',
#  'pacific grove',
#  'hilo',
#  'saint-georges',
#  'dakar',
#  'ostrovnoy',
#  'kavieng',
#  'sumenep',
#  'malwan',
#  'zeya',
#  'sibolga',
#  'yumen',
#  'onalaska',
#  'miri',
#  'mayo',
#  'lichtenburg',
#  'dalgopol',
#  'bela',
#  'victoria',
#  'khorixas',
#  'sataua',
#  'acapulco',
#  'real',
#  'leningradskiy',
#  'devils lake',
#  'san quintin',
#  'orlik',
#  'katsuura',
#  'cabo san lucas',
#  'thespiai',
#  'tharad',
#  'krasnomayskiy',
#  'hay river',
#  'bossangoa',
#  'tomohon',
#  'lakes entrance',
#  'viedma',
#  'bambous virieux',
#  'yeniseysk',
#  'ilulissat',
#  'phalaborwa',
#  'alsfeld',
#  'mahebourg',
#  'hrymayliv',
#  'torbay',
#  'muyezerskiy',
#  'rawson',
#  'trat',
#  'stornoway',
#  'mayumba',
#  'port-de-paix',
#  'ukiah',
#  'kharitonovo',
#  'saleaula',
#  'srednekolymsk',
#  'bastrop',
#  'hermanus',
#  'mehamn',
#  'barawe',
#  'antalaha',
#  'roswell',
#  'muzhi',
#  'bria',
#  'oktyabrskoye',
#  'california city',
#  'broome',
#  'saquena',
#  'san policarpo',
#  'chuguyevka',
#  'alofi',
#  'gulshat',
#  'collie',
#  'butaritari',
#  'calvia',
#  'codrington',
#  'kununurra',
#  'dingle',
#  'brumado',
#  'palabuhanratu',
#  'awjilah',
#  'skjervoy',
#  'launceston',
#  'yulara',
#  'dudinka',
#  'mindelo',
#  'grindavik',
#  'manihari',
#  'faanui',
#  'labytnangi',
#  'eastchester',
#  'sedriano',
#  'weifang',
#  'blonduos',
#  'cairns',
#  'beringovskiy',
#  'belushya guba',
#  'chuy',
#  'maceio',
#  'sur',
#  'chongwe',
#  'katsiveli',
#  'san patricio',
#  'karratha',
#  'carballo',
#  'kanchanaburi',
#  'san cristobal',
#  'saurimo',
#  'mitikas',
#  'arrifes',
#  'havre-saint-pierre',
#  'kamuli',
#  'brae',
#  'rockland',
#  'indulang',
#  'christchurch',
#  'sibirtsevo',
#  'kidal',
#  'yerbogachen',
#  'grimshaw',
#  'inhambane',
#  'hovd',
#  'esmeraldas',
#  'moundsville',
#  'arraial do cabo',
#  'meulaboh',
#  'kisangani',
#  'balao',
#  'statesboro',
#  'fallon',
#  'dasoguz',
#  'east london',
#  'kendari',
#  'lorengau',
#  'padang',
#  'jitauna',
#  'tumannyy',
#  'aksarka',
#  'hammerfest',
#  'najran',
#  'crab hill',
#  'richards bay',
#  'iqaluit',
#  'teguldet',
#  'matamoros',
#  'boa vista',
#  'qasigiannguit',
#  'marawi',
#  'selikhino',
#  'geraldton',
#  'turayf',
#  'juifang',
#  'samarai',
#  'quelimane',
#  'tabuk',
#  'clyde river',
#  'killam',
#  'sobolevo',
#  'chunoyar',
#  'general roca',
#  'mizan teferi',
#  'ouidah',
#  'centralina',
#  'boueni',
#  'lubumbashi',
#  'kerteh',
#  'mercedes',
#  'golden gate',
#  'kattivakkam',
#  'boulder city',
#  'dhanaula',
#  'fairbanks',
#  'mandalgovi',
#  'ixtapa',
#  'hanumangarh',
#  'husavik',
#  'abu zabad',
#  'tandil',
#  'fort nelson',
#  'petropavlovsk-kamchatskiy',
#  'mount isa',
#  'kavaratti',
#  'attawapiskat',
#  'nguiu',
#  'bilma',
#  'umzimvubu',
#  'vila velha',
#  'malpe',
#  'marcona',
#  'worland',
#  'iskandar',
#  'nanortalik',
#  'batagay-alyta',
#  'finschhafen',
#  'komsomolskiy',
#  'tibagi',
#  'pitimbu',
#  'aitape',
#  'san carlos de bariloche',
#  'glenwood springs',
#  'cap malheureux',
#  'bucerias',
#  'vostok',
#  'namibe',
#  'wani',
#  'imuris',
#  'manokwari',
#  'zhigansk',
#  'kungurtug',
#  'camana',
#  'marau',
#  'rovinj',
#  'vicksburg',
#  'calvinia',
#  'kanye',
#  'luau',
#  'neiafu',
#  'baykit',
#  'namatanai',
#  'nantai',
#  'lufilufi',
#  'visnes',
#  'magadan',
#  'baoqing',
#  'lasa',
#  'kismayo',
#  'luganville',
#  'bentiu',
#  'hamilton',
#  'bodden town',
#  'butembo',
#  'nemuro',
#  'lushunkou',
#  'kuytun',
#  'cobija',
#  'dharchula',
#  'santa fe',
#  'caineni',
#  'comodoro rivadavia',
#  'madawaska',
#  'aflu',
#  'formoso do araguaia',
#  'bangassou',
#  'baijiantan',
#  'halalo',
#  'liverpool',
#  'warqla',
#  'tuatapere',
#  'uinskoye',
#  'darhan',
#  'baykalovo',
#  'katangli',
#  'kondinskoye',
#  'alihe',
#  'wahran',
#  'paita',
#  'grafton',
#  'nome',
#  'coquimbo',
#  'grand gaube',
#  'chernelytsya',
#  'amiens',
#  'muroto',
#  'pamanukan',
#  'zhigalovo',
#  'wasilla',
#  'calama',
#  'ust-kamchatsk',
#  'rolim de moura',
#  'minna',
#  'nelson bay',
#  'dauriya',
#  'dibrugarh',
#  'marrakesh',
#  'heihe',
#  'basco',
#  'lazaro cardenas',
#  'cayenne',
#  'kyabe',
#  'axim',
#  'pauini',
#  'azare',
#  'kazalinsk',
#  'tsihombe',
#  'linares',
#  'shimoda',
#  'sangar',
#  'tahe',
#  'upington',
#  'muriti',
#  'kuito',
#  'billings',
#  'langenburg',
#  'sinkat',
#  'palmer',
#  'flinders',
#  'louisbourg',
#  'haibowan',
#  'amudat',
#  'amga',
#  'fort frances',
#  'camabatela',
#  'barcelona',
#  'huarmey',
#  'ramgarh',
#  'boulsa',
#  'shache',
#  'kirya',
#  'hofn',
#  'yura',
#  'arlon',
#  'ponta delgada',
#  'aklavik',
#  'kirakira',
#  'havoysund',
#  'belaya gora',
#  'rock sound',
#  'kamenskoye',
#  'sao joao da barra',
#  'zhifang',
#  'walvis bay',
#  'kaeo',
#  'weligama',
#  'sayyan',
#  'mpika',
#  'maumere',
#  'victor harbor',
#  'campana',
#  'camacupa',
#  'piopio',
#  'svetlogorsk',
#  'yueyang',
#  'ouango',
#  'palora',
#  'vanimo',
#  'camacha',
#  'mandera',
#  'tautira',
#  'erenhot',
#  'evensk',
#  'lira',
#  'andenes',
#  'ha tinh',
#  'saint anthony',
#  'coahuayana',
#  'shibarghan',
#  'mandurah',
#  'saldanha',
#  'el tigre',
#  'agucadoura',
#  'coos bay',
#  'sao sebastiao',
#  'morro bay',
#  'vitim',
#  'strezhevoy',
#  'tecoanapa',
#  'lewiston',
#  'krasnoselkup',
#  'rafaela',
#  'wanning',
#  'izberbash',
#  'puerto suarez',
#  'darnah',
#  'genhe',
#  'nipawin',
#  'dzaoudzi',
#  'naze',
#  'anyama',
#  'le port',
#  'vinh yen',
#  'vryburg',
#  'yukamenskoye',
#  'kalmunai',
#  'ruatoria',
#  'curup',
#  'kurilsk',
#  'saint-leu',
#  'iacu',
#  'kasempa',
#  'kabompo',
#  'kangaatsiaq',
#  'weihai',
#  'labutta',
#  'la union',
#  'majalgaon',
#  'prata',
#  'santa rosa',
#  'kassala',
#  'herouville-saint-clair',
#  'atar',
#  'linkou',
#  'opelousas',
#  'novo aripuana',
#  'barbastro',
#  'puerto escondido',
#  'camocim',
#  'okha',
#  'marystown',
#  'stokmarknes',
#  'yeppoon',
#  'quatre cocos',
#  'jinchang',
#  'bolungarvik',
#  'coracora',
#  'mpongwe',
#  'berdigestyakh',
#  'vagur',
#  'mocuba',
#  'pisco',
#  'zemio',
#  'santo nino',
#  'mrirt',
#  'socorro',
#  'trairi',
#  'lagos',
#  'gemena',
#  'kirksville',
#  'avera',
#  'mangrol',
#  'sarandi',
#  'ziyamet',
#  'lugovskiy',
#  'zhangye',
#  'nicoya',
#  'shingu',
#  'bonavista',
#  'susaki',
#  'bulolo',
#  'gerede',
#  'doctor pedro p. pena',
#  'conakry',
#  'hobyo',
#  'lakhimpur',
#  'xiaoweizhai',
#  'hengshui',
#  'payo',
#  'ayagoz',
#  'guane',
#  'bollnas',
#  'araouane',
#  'kachug',
#  'arawa',
#  'prince rupert',
#  'havelock',
#  'ejea de los caballeros',
#  'santa cruz',
#  'ust-karsk',
#  'mao',
#  'rocha',
#  'half moon bay',
#  'seoul',
#  'inndyr',
#  'deputatskiy',
#  'verkhnyaya inta',
#  'envira',
#  'martinsburg',
#  'muscat',
#  'oranjemund',
#  'birao',
#  'arrecife',
#  'durazno',
#  'edd',
#  'high level',
#  'tanete',
#  'ayorou',
#  'khovu-aksy',
#  'makakilo city',
#  'krasnovishersk',
#  'bu salim',
#  'odienne',
#  'raudeberg',
#  'dzhusaly',
#  'dwarka',
#  'floro',
#  'bendigo',
#  'newport',
#  'inuvik',
#  'shiyan',
#  'jiddah',
#  'lahij',
#  'yelatma',
#  'tromso',
#  'ulladulla',
#  'urengoy',
#  'opobo',
#  'murdochville',
#  'parainen',
#  'suzu',
#  'bandarbeyla',
#  'puerto leguizamo',
#  'pishva',
#  'saint-joseph',
#  'bemidji',
#  'merrill',
#  'caborca',
#  'middelkerke',
#  'klaksvik',
#  'russell',
#  'poum',
#  'liberty',
#  'pulivendla',
#  'ulaangom',
#  'omaha',
#  'kindu',
#  'bonthe',
#  'bayugan',
#  'auckland',
#  'lovozero',
#  'galiwinku',
#  'anda',
#  'pueblo',
#  'kharabali',
#  'waipawa',
#  'isangel',
#  'balykshi',
#  'sargatskoye',
#  'sarangani',
#  'artigas',
#  'portpatrick',
#  'minab',
#  'voh',
#  'nhamunda',
#  'fundacion',
#  'burnie',
#  'setermoen',
#  'jieshi',
#  'grootfontein',
#  'venice',
#  'bourail',
#  'iracoubo',
#  'taltal',
#  'manoel urbano',
#  'la ronge',
#  'novaya igirma',
#  'horn',
#  'mirabad',
#  'khilok',
#  'hervey bay',
#  'beaverlodge',
#  'marsh harbour',
#  'ocampo',
#  'dauphin',
#  'megion',
#  'cuamba',
#  'urdzhar',
#  'tiarei',
#  'leninskoye',
#  'ituni',
#  'maniitsoq',
#  'ust-nera',
#  'dumbravita',
#  'teknaf',
#  'ugoofaaru',
#  'karaton',
#  'malumfashi',
#  'port-gentil',
#  'puerto wilches',
#  'puerto colombia',
#  'cravo norte',
#  'miles city',
#  'tartagal',
#  'palana',
#  'shellbrook',
#  'mikuni',
#  'santiago del estero',
#  'hunza',
#  'karachi',
#  'balkanabat',
#  'chillan',
#  'katete',
#  'road town',
#  'phayao',
#  'mission bend',
#  'matara',
#  'hami',
#  'tyshkivka',
#  'mareeba',
#  'kalaleh',
#  'agadez',
#  'parras',
#  'mutsamudu',
#  'micheweni',
#  'kahului',
#  'miguel hidalgo',
#  'langxiang',
#  'prado',
#  'bukama',
#  'san-pedro',
#  'sovetskaya gavan',
#  'uk',
#  'te anau',
#  'kupang',
#  'zhicheng',
#  'morant bay',
#  'uribia',
#  'stryn',
#  'lomas de sargentillo',
#  'qaracala',
#  'basirhat']

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        print("-----------------------------")
        print(f'Querying Data for {city}')
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Country": city_country,
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Current Description": city_description})
        
        print("-----------------------------")
        print(f'Appending Data for {city}')
        print("-----------------------------")

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        print("-----------------------------")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | santona
# -----------------------------
# Querying Data for santona
# -----------------------------
# Appending Data for santona
# Processing Record 2 of Set 1 | illoqqortoormiut
# -----------------------------
# Querying Data for illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | hithadhoo
# -----------------------------
# Querying Data for hithadhoo
# -----------------------------
# Appending Data for hithadhoo
# Processing Record 4 of Set 1 | chernyshevskiy
# -----------------------------
# Querying Data for chernyshevskiy
# -----------------------------
# Appending Data for chernyshevskiy
# Processing Record 5 of Set 1 | tadine
# -----------------------------
# Querying Data for tadine
# -----------------------------
# Appending Data for tadine
# Processing Record 6 of Set 1 | praxedis guerrero
# -----------------------------
# Querying Data for praxedis guerrero
# -----------------------------
# Appending Data for praxedis guerrero
# Processing Record 7 of Set 1 | georgetown
# -----------------------------
# Querying Data for georgetown
# -----------------------------
# Appending Data for georgetown
# Processing Record 8 of Set 1 | lebu
# -----------------------------
# Querying Data for lebu
# -----------------------------
# Appending Data for lebu
# Processing Record 9 of Set 1 | thompson
# -----------------------------
# Querying Data for thompson
# -----------------------------
# Appending Data for thompson
# Processing Record 10 of Set 1 | new norfolk
# -----------------------------
# Querying Data for new norfolk
# -----------------------------
# Appending Data for new norfolk
# Processing Record 11 of Set 1 | avarua
# -----------------------------
# Querying Data for avarua
# -----------------------------
# Appending Data for avarua
# Processing Record 12 of Set 1 | cockburn town
# -----------------------------
# Querying Data for cockburn town
# -----------------------------
# Appending Data for cockburn town
# Processing Record 13 of Set 1 | jamestown
# -----------------------------
# Querying Data for jamestown
# -----------------------------
# Appending Data for jamestown
# Processing Record 14 of Set 1 | barentsburg
# -----------------------------
# Querying Data for barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 1 | keroka
# -----------------------------
# Querying Data for keroka
# -----------------------------
# Appending Data for keroka
# Processing Record 16 of Set 1 | barrow
# -----------------------------
# Querying Data for barrow
# -----------------------------
# Appending Data for barrow
# Processing Record 17 of Set 1 | luderitz
# -----------------------------
# Querying Data for luderitz
# -----------------------------
# Appending Data for luderitz
# Processing Record 18 of Set 1 | esperance
# -----------------------------
# Querying Data for esperance
# -----------------------------
# Appending Data for esperance
# Processing Record 19 of Set 1 | rikitea
# -----------------------------
# Querying Data for rikitea
# -----------------------------
# Appending Data for rikitea
# Processing Record 20 of Set 1 | busselton
# -----------------------------
# Querying Data for busselton
# -----------------------------
# Appending Data for busselton
# Processing Record 21 of Set 1 | acajutla
# -----------------------------
# Querying Data for acajutla
# -----------------------------
# Appending Data for acajutla
# Processing Record 22 of Set 1 | broken hill
# -----------------------------
# Querying Data for broken hill
# -----------------------------
# Appending Data for broken hill
# Processing Record 23 of Set 1 | saskylakh
# -----------------------------
# Querying Data for saskylakh
# -----------------------------
# Appending Data for saskylakh
# Processing Record 24 of Set 1 | hualmay
# -----------------------------
# Querying Data for hualmay
# -----------------------------
# Appending Data for hualmay
# Processing Record 25 of Set 1 | beian
# -----------------------------
# Querying Data for beian
# -----------------------------
# Appending Data for beian
# Processing Record 26 of Set 1 | mar del plata
# -----------------------------
# Querying Data for mar del plata
# -----------------------------
# Appending Data for mar del plata
# Processing Record 27 of Set 1 | punta arenas
# -----------------------------
# Querying Data for punta arenas
# -----------------------------
# Appending Data for punta arenas
# Processing Record 28 of Set 1 | bethel
# -----------------------------
# Querying Data for bethel
# -----------------------------
# Appending Data for bethel
# Processing Record 29 of Set 1 | bathsheba
# -----------------------------
# Querying Data for bathsheba
# -----------------------------
# Appending Data for bathsheba
# Processing Record 30 of Set 1 | samusu
# -----------------------------
# Querying Data for samusu
# City not found. Skipping...
# Processing Record 31 of Set 1 | erzin
# -----------------------------
# Querying Data for erzin
# -----------------------------
# Appending Data for erzin
# Processing Record 32 of Set 1 | taolanaro
# -----------------------------
# Querying Data for taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | guerrero negro
# -----------------------------
# Querying Data for guerrero negro
# -----------------------------
# Appending Data for guerrero negro
# Processing Record 34 of Set 1 | ushuaia
# -----------------------------
# Querying Data for ushuaia
# -----------------------------
# Appending Data for ushuaia
# Processing Record 35 of Set 1 | juneau
# -----------------------------
# Querying Data for juneau
# -----------------------------
# Appending Data for juneau
# Processing Record 36 of Set 1 | porto novo
# -----------------------------
# Querying Data for porto novo
# -----------------------------
# Appending Data for porto novo
# Processing Record 37 of Set 1 | lhokseumawe
# -----------------------------
# Querying Data for lhokseumawe
# -----------------------------
# Appending Data for lhokseumawe
# Processing Record 38 of Set 1 | gwadar
# -----------------------------
# Querying Data for gwadar
# -----------------------------
# Appending Data for gwadar
# Processing Record 39 of Set 1 | bredasdorp
# -----------------------------
# Querying Data for bredasdorp
# -----------------------------
# Appending Data for bredasdorp
# Processing Record 40 of Set 1 | charters towers
# -----------------------------
# Querying Data for charters towers
# -----------------------------
# Appending Data for charters towers
# Processing Record 41 of Set 1 | pevek
# -----------------------------
# Querying Data for pevek
# -----------------------------
# Appending Data for pevek
# Processing Record 42 of Set 1 | sentyabrskiy
# -----------------------------
# Querying Data for sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 1 | castro
# -----------------------------
# Querying Data for castro
# -----------------------------
# Appending Data for castro
# Processing Record 44 of Set 1 | anadyr
# -----------------------------
# Querying Data for anadyr
# -----------------------------
# Appending Data for anadyr
# Processing Record 45 of Set 1 | souillac
# -----------------------------
# Querying Data for souillac
# -----------------------------
# Appending Data for souillac
# Processing Record 46 of Set 1 | port hedland
# -----------------------------
# Querying Data for port hedland
# -----------------------------
# Appending Data for port hedland
# Processing Record 47 of Set 1 | zabol
# -----------------------------
# Querying Data for zabol
# -----------------------------
# Appending Data for zabol
# Processing Record 48 of Set 1 | kruisfontein
# -----------------------------
# Querying Data for kruisfontein
# -----------------------------
# Appending Data for kruisfontein
# Processing Record 49 of Set 1 | vaini
# -----------------------------
# Querying Data for vaini
# -----------------------------
# Appending Data for vaini
# Processing Record 50 of Set 1 | hobart
# -----------------------------
# Querying Data for hobart
# -----------------------------
# Appending Data for hobart
# Processing Record 1 of Set 2 | vestmanna
# -----------------------------
# Querying Data for vestmanna
# -----------------------------
# Appending Data for vestmanna
# Processing Record 2 of Set 2 | fortuna
# -----------------------------
# Querying Data for fortuna
# -----------------------------
# Appending Data for fortuna
# Processing Record 3 of Set 2 | albany
# -----------------------------
# Querying Data for albany
# -----------------------------
# Appending Data for albany
# Processing Record 4 of Set 2 | teya
# -----------------------------
# Querying Data for teya
# -----------------------------
# Appending Data for teya
# Processing Record 5 of Set 2 | olafsvik
# -----------------------------
# Querying Data for olafsvik
# -----------------------------
# Appending Data for olafsvik
# Processing Record 6 of Set 2 | upernavik
# -----------------------------
# Querying Data for upernavik
# -----------------------------
# Appending Data for upernavik
# Processing Record 7 of Set 2 | dongying
# -----------------------------
# Querying Data for dongying
# -----------------------------
# Appending Data for dongying
# Processing Record 8 of Set 2 | mocambique
# -----------------------------
# Querying Data for mocambique
# City not found. Skipping...
# Processing Record 9 of Set 2 | kamenka
# -----------------------------
# Querying Data for kamenka
# -----------------------------
# Appending Data for kamenka
# Processing Record 10 of Set 2 | tasiilaq
# -----------------------------
# Querying Data for tasiilaq
# -----------------------------
# Appending Data for tasiilaq
# Processing Record 11 of Set 2 | kaitangata
# -----------------------------
# Querying Data for kaitangata
# -----------------------------
# Appending Data for kaitangata
# Processing Record 12 of Set 2 | williamsport
# -----------------------------
# Querying Data for williamsport
# -----------------------------
# Appending Data for williamsport
# Processing Record 13 of Set 2 | cape town
# -----------------------------
# Querying Data for cape town
# -----------------------------
# Appending Data for cape town
# Processing Record 14 of Set 2 | pandan
# -----------------------------
# Querying Data for pandan
# -----------------------------
# Appending Data for pandan
# Processing Record 15 of Set 2 | ribnitz-damgarten
# -----------------------------
# Querying Data for ribnitz-damgarten
# -----------------------------
# Appending Data for ribnitz-damgarten
# Processing Record 16 of Set 2 | kodiak
# -----------------------------
# Querying Data for kodiak
# -----------------------------
# Appending Data for kodiak
# Processing Record 17 of Set 2 | kapaa
# -----------------------------
# Querying Data for kapaa
# -----------------------------
# Appending Data for kapaa
# Processing Record 18 of Set 2 | narsaq
# -----------------------------
# Querying Data for narsaq
# -----------------------------
# Appending Data for narsaq
# Processing Record 19 of Set 2 | saint-francois
# -----------------------------
# Querying Data for saint-francois
# -----------------------------
# Appending Data for saint-francois
# Processing Record 20 of Set 2 | salalah
# -----------------------------
# Querying Data for salalah
# -----------------------------
# Appending Data for salalah
# Processing Record 21 of Set 2 | hasaki
# -----------------------------
# Querying Data for hasaki
# -----------------------------
# Appending Data for hasaki
# Processing Record 22 of Set 2 | puerto ayora
# -----------------------------
# Querying Data for puerto ayora
# -----------------------------
# Appending Data for puerto ayora
# Processing Record 23 of Set 2 | kokoda
# -----------------------------
# Querying Data for kokoda
# -----------------------------
# Appending Data for kokoda
# Processing Record 24 of Set 2 | giyani
# -----------------------------
# Querying Data for giyani
# -----------------------------
# Appending Data for giyani
# Processing Record 25 of Set 2 | dikson
# -----------------------------
# Querying Data for dikson
# -----------------------------
# Appending Data for dikson
# Processing Record 26 of Set 2 | nuuk
# -----------------------------
# Querying Data for nuuk
# -----------------------------
# Appending Data for nuuk
# Processing Record 27 of Set 2 | vestmannaeyjar
# -----------------------------
# Querying Data for vestmannaeyjar
# -----------------------------
# Appending Data for vestmannaeyjar
# Processing Record 28 of Set 2 | coihaique
# -----------------------------
# Querying Data for coihaique
# -----------------------------
# Appending Data for coihaique
# Processing Record 29 of Set 2 | sao filipe
# -----------------------------
# Querying Data for sao filipe
# -----------------------------
# Appending Data for sao filipe
# Processing Record 30 of Set 2 | luanda
# -----------------------------
# Querying Data for luanda
# -----------------------------
# Appending Data for luanda
# Processing Record 31 of Set 2 | port alfred
# -----------------------------
# Querying Data for port alfred
# -----------------------------
# Appending Data for port alfred
# Processing Record 32 of Set 2 | faya
# -----------------------------
# Querying Data for faya
# -----------------------------
# Appending Data for faya
# Processing Record 33 of Set 2 | port lincoln
# -----------------------------
# Querying Data for port lincoln
# -----------------------------
# Appending Data for port lincoln
# Processing Record 34 of Set 2 | vilhena
# -----------------------------
# Querying Data for vilhena
# -----------------------------
# Appending Data for vilhena
# Processing Record 35 of Set 2 | morgan city
# -----------------------------
# Querying Data for morgan city
# -----------------------------
# Appending Data for morgan city
# Processing Record 36 of Set 2 | roma
# -----------------------------
# Querying Data for roma
# -----------------------------
# Appending Data for roma
# Processing Record 37 of Set 2 | carnarvon
# -----------------------------
# Querying Data for carnarvon
# -----------------------------
# Appending Data for carnarvon
# Processing Record 38 of Set 2 | ayan
# -----------------------------
# Querying Data for ayan
# -----------------------------
# Appending Data for ayan
# Processing Record 39 of Set 2 | korla
# -----------------------------
# Querying Data for korla
# -----------------------------
# Appending Data for korla
# Processing Record 40 of Set 2 | constitucion
# -----------------------------
# Querying Data for constitucion
# -----------------------------
# Appending Data for constitucion
# Processing Record 41 of Set 2 | koroni
# -----------------------------
# Querying Data for koroni
# -----------------------------
# Appending Data for koroni
# Processing Record 42 of Set 2 | laguna
# -----------------------------
# Querying Data for laguna
# -----------------------------
# Appending Data for laguna
# Processing Record 43 of Set 2 | ponta do sol
# -----------------------------
# Querying Data for ponta do sol
# -----------------------------
# Appending Data for ponta do sol
# Processing Record 44 of Set 2 | kargopol
# -----------------------------
# Querying Data for kargopol
# -----------------------------
# Appending Data for kargopol
# Processing Record 45 of Set 2 | mehndawal
# -----------------------------
# Querying Data for mehndawal
# -----------------------------
# Appending Data for mehndawal
# Processing Record 46 of Set 2 | chumikan
# -----------------------------
# Querying Data for chumikan
# -----------------------------
# Appending Data for chumikan
# Processing Record 47 of Set 2 | khatanga
# -----------------------------
# Querying Data for khatanga
# -----------------------------
# Appending Data for khatanga
# Processing Record 48 of Set 2 | gamba
# -----------------------------
# Querying Data for gamba
# -----------------------------
# Appending Data for gamba
# Processing Record 49 of Set 2 | jumla
# -----------------------------
# Querying Data for jumla
# -----------------------------
# Appending Data for jumla
# Processing Record 50 of Set 2 | san juan
# -----------------------------
# Querying Data for san juan
# -----------------------------
# Appending Data for san juan
# Processing Record 1 of Set 3 | inta
# -----------------------------
# Querying Data for inta
# -----------------------------
# Appending Data for inta
# Processing Record 2 of Set 3 | ijaki
# -----------------------------
# Querying Data for ijaki
# City not found. Skipping...
# Processing Record 3 of Set 3 | ancud
# -----------------------------
# Querying Data for ancud
# -----------------------------
# Appending Data for ancud
# Processing Record 4 of Set 3 | touros
# -----------------------------
# Querying Data for touros
# -----------------------------
# Appending Data for touros
# Processing Record 5 of Set 3 | rosita
# -----------------------------
# Querying Data for rosita
# -----------------------------
# Appending Data for rosita
# Processing Record 6 of Set 3 | martapura
# -----------------------------
# Querying Data for martapura
# -----------------------------
# Appending Data for martapura
# Processing Record 7 of Set 3 | davlekanovo
# -----------------------------
# Querying Data for davlekanovo
# -----------------------------
# Appending Data for davlekanovo
# Processing Record 8 of Set 3 | jiuquan
# -----------------------------
# Querying Data for jiuquan
# -----------------------------
# Appending Data for jiuquan
# Processing Record 9 of Set 3 | saint george
# -----------------------------
# Querying Data for saint george
# -----------------------------
# Appending Data for saint george
# Processing Record 10 of Set 3 | kharp
# -----------------------------
# Querying Data for kharp
# -----------------------------
# Appending Data for kharp
# Processing Record 11 of Set 3 | mys shmidta
# -----------------------------
# Querying Data for mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 3 | san andres
# -----------------------------
# Querying Data for san andres
# -----------------------------
# Appending Data for san andres
# Processing Record 13 of Set 3 | nikolskoye
# -----------------------------
# Querying Data for nikolskoye
# -----------------------------
# Appending Data for nikolskoye
# Processing Record 14 of Set 3 | champerico
# -----------------------------
# Querying Data for champerico
# -----------------------------
# Appending Data for champerico
# Processing Record 15 of Set 3 | provideniya
# -----------------------------
# Querying Data for provideniya
# -----------------------------
# Appending Data for provideniya
# Processing Record 16 of Set 3 | ribeira grande
# -----------------------------
# Querying Data for ribeira grande
# -----------------------------
# Appending Data for ribeira grande
# Processing Record 17 of Set 3 | atuona
# -----------------------------
# Querying Data for atuona
# -----------------------------
# Appending Data for atuona
# Processing Record 18 of Set 3 | los llanos de aridane
# -----------------------------
# Querying Data for los llanos de aridane
# -----------------------------
# Appending Data for los llanos de aridane
# Processing Record 19 of Set 3 | tuma
# -----------------------------
# Querying Data for tuma
# -----------------------------
# Appending Data for tuma
# Processing Record 20 of Set 3 | lata
# -----------------------------
# Querying Data for lata
# -----------------------------
# Appending Data for lata
# Processing Record 21 of Set 3 | qaanaaq
# -----------------------------
# Querying Data for qaanaaq
# -----------------------------
# Appending Data for qaanaaq
# Processing Record 22 of Set 3 | antofagasta
# -----------------------------
# Querying Data for antofagasta
# -----------------------------
# Appending Data for antofagasta
# Processing Record 23 of Set 3 | mataura
# -----------------------------
# Querying Data for mataura
# -----------------------------
# Appending Data for mataura
# Processing Record 24 of Set 3 | sechura
# -----------------------------
# Querying Data for sechura
# -----------------------------
# Appending Data for sechura
# Processing Record 25 of Set 3 | caxito
# -----------------------------
# Querying Data for caxito
# -----------------------------
# Appending Data for caxito
# Processing Record 26 of Set 3 | huilong
# -----------------------------
# Querying Data for huilong
# -----------------------------
# Appending Data for huilong
# Processing Record 27 of Set 3 | labuhan
# -----------------------------
# Querying Data for labuhan
# -----------------------------
# Appending Data for labuhan
# Processing Record 28 of Set 3 | barkhan
# -----------------------------
# Querying Data for barkhan
# -----------------------------
# Appending Data for barkhan
# Processing Record 29 of Set 3 | tual
# -----------------------------
# Querying Data for tual
# -----------------------------
# Appending Data for tual
# Processing Record 30 of Set 3 | chokurdakh
# -----------------------------
# Querying Data for chokurdakh
# -----------------------------
# Appending Data for chokurdakh
# Processing Record 31 of Set 3 | yellowknife
# -----------------------------
# Querying Data for yellowknife
# -----------------------------
# Appending Data for yellowknife
# Processing Record 32 of Set 3 | joao pinheiro
# -----------------------------
# Querying Data for joao pinheiro
# -----------------------------
# Appending Data for joao pinheiro
# Processing Record 33 of Set 3 | tiksi
# -----------------------------
# Querying Data for tiksi
# -----------------------------
# Appending Data for tiksi
# Processing Record 34 of Set 3 | lompoc
# -----------------------------
# Querying Data for lompoc
# -----------------------------
# Appending Data for lompoc
# Processing Record 35 of Set 3 | burica
# -----------------------------
# Querying Data for burica
# City not found. Skipping...
# Processing Record 36 of Set 3 | tabou
# -----------------------------
# Querying Data for tabou
# -----------------------------
# Appending Data for tabou
# Processing Record 37 of Set 3 | bengkulu
# -----------------------------
# Querying Data for bengkulu
# -----------------------------
# Appending Data for bengkulu
# Processing Record 38 of Set 3 | saint-philippe
# -----------------------------
# Querying Data for saint-philippe
# -----------------------------
# Appending Data for saint-philippe
# Processing Record 39 of Set 3 | cherskiy
# -----------------------------
# Querying Data for cherskiy
# -----------------------------
# Appending Data for cherskiy
# Processing Record 40 of Set 3 | abu samrah
# -----------------------------
# Querying Data for abu samrah
# -----------------------------
# Appending Data for abu samrah
# Processing Record 41 of Set 3 | jimenez
# -----------------------------
# Querying Data for jimenez
# -----------------------------
# Appending Data for jimenez
# Processing Record 42 of Set 3 | talnakh
# -----------------------------
# Querying Data for talnakh
# -----------------------------
# Appending Data for talnakh
# Processing Record 43 of Set 3 | sinnamary
# -----------------------------
# Querying Data for sinnamary
# -----------------------------
# Appending Data for sinnamary
# Processing Record 44 of Set 3 | bluff
# -----------------------------
# Querying Data for bluff
# -----------------------------
# Appending Data for bluff
# Processing Record 45 of Set 3 | norman wells
# -----------------------------
# Querying Data for norman wells
# -----------------------------
# Appending Data for norman wells
# Processing Record 46 of Set 3 | port hardy
# -----------------------------
# Querying Data for port hardy
# -----------------------------
# Appending Data for port hardy
# Processing Record 47 of Set 3 | safaga
# -----------------------------
# Querying Data for safaga
# -----------------------------
# Appending Data for safaga
# Processing Record 48 of Set 3 | milkovo
# -----------------------------
# Querying Data for milkovo
# -----------------------------
# Appending Data for milkovo
# Processing Record 49 of Set 3 | barreiras
# -----------------------------
# Querying Data for barreiras
# -----------------------------
# Appending Data for barreiras
# Processing Record 50 of Set 3 | puerto baquerizo moreno
# -----------------------------
# Querying Data for puerto baquerizo moreno
# -----------------------------
# Appending Data for puerto baquerizo moreno
# Processing Record 1 of Set 4 | sitka
# -----------------------------
# Querying Data for sitka
# -----------------------------
# Appending Data for sitka
# Processing Record 2 of Set 4 | amderma
# -----------------------------
# Querying Data for amderma
# City not found. Skipping...
# Processing Record 3 of Set 4 | inverell
# -----------------------------
# Querying Data for inverell
# -----------------------------
# Appending Data for inverell
# Processing Record 4 of Set 4 | airai
# -----------------------------
# Querying Data for airai
# -----------------------------
# Appending Data for airai
# Processing Record 5 of Set 4 | lavrentiya
# -----------------------------
# Querying Data for lavrentiya
# -----------------------------
# Appending Data for lavrentiya
# Processing Record 6 of Set 4 | lagoa
# -----------------------------
# Querying Data for lagoa
# -----------------------------
# Appending Data for lagoa
# Processing Record 7 of Set 4 | kenai
# -----------------------------
# Querying Data for kenai
# -----------------------------
# Appending Data for kenai
# Processing Record 8 of Set 4 | tura
# -----------------------------
# Querying Data for tura
# -----------------------------
# Appending Data for tura
# Processing Record 9 of Set 4 | kosa
# -----------------------------
# Querying Data for kosa
# -----------------------------
# Appending Data for kosa
# Processing Record 10 of Set 4 | longyearbyen
# -----------------------------
# Querying Data for longyearbyen
# -----------------------------
# Appending Data for longyearbyen
# Processing Record 11 of Set 4 | cidreira
# -----------------------------
# Querying Data for cidreira
# -----------------------------
# Appending Data for cidreira
# Processing Record 12 of Set 4 | matrei
# -----------------------------
# Querying Data for matrei
# City not found. Skipping...
# Processing Record 13 of Set 4 | nalut
# -----------------------------
# Querying Data for nalut
# -----------------------------
# Appending Data for nalut
# Processing Record 14 of Set 4 | fethiye
# -----------------------------
# Querying Data for fethiye
# -----------------------------
# Appending Data for fethiye
# Processing Record 15 of Set 4 | gizo
# -----------------------------
# Querying Data for gizo
# -----------------------------
# Appending Data for gizo
# Processing Record 16 of Set 4 | severo-kurilsk
# -----------------------------
# Querying Data for severo-kurilsk
# -----------------------------
# Appending Data for severo-kurilsk
# Processing Record 17 of Set 4 | tessalit
# -----------------------------
# Querying Data for tessalit
# -----------------------------
# Appending Data for tessalit
# Processing Record 18 of Set 4 | nizhneyansk
# -----------------------------
# Querying Data for nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 4 | port hawkesbury
# -----------------------------
# Querying Data for port hawkesbury
# -----------------------------
# Appending Data for port hawkesbury
# Processing Record 20 of Set 4 | mount gambier
# -----------------------------
# Querying Data for mount gambier
# -----------------------------
# Appending Data for mount gambier
# Processing Record 21 of Set 4 | grand river south east
# -----------------------------
# Querying Data for grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 4 | vesoul
# -----------------------------
# Querying Data for vesoul
# -----------------------------
# Appending Data for vesoul
# Processing Record 23 of Set 4 | salinopolis
# -----------------------------
# Querying Data for salinopolis
# -----------------------------
# Appending Data for salinopolis
# Processing Record 24 of Set 4 | vaitupu
# -----------------------------
# Querying Data for vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | okhotsk
# -----------------------------
# Querying Data for okhotsk
# -----------------------------
# Appending Data for okhotsk
# Processing Record 26 of Set 4 | port blair
# -----------------------------
# Querying Data for port blair
# -----------------------------
# Appending Data for port blair
# Processing Record 27 of Set 4 | port elizabeth
# -----------------------------
# Querying Data for port elizabeth
# -----------------------------
# Appending Data for port elizabeth
# Processing Record 28 of Set 4 | tuktoyaktuk
# -----------------------------
# Querying Data for tuktoyaktuk
# -----------------------------
# Appending Data for tuktoyaktuk
# Processing Record 29 of Set 4 | mackay
# -----------------------------
# Querying Data for mackay
# -----------------------------
# Appending Data for mackay
# Processing Record 30 of Set 4 | saint-pierre
# -----------------------------
# Querying Data for saint-pierre
# -----------------------------
# Appending Data for saint-pierre
# Processing Record 31 of Set 4 | aripuana
# -----------------------------
# Querying Data for aripuana
# -----------------------------
# Appending Data for aripuana
# Processing Record 32 of Set 4 | eskasem
# -----------------------------
# Querying Data for eskasem
# City not found. Skipping...
# Processing Record 33 of Set 4 | pacific grove
# -----------------------------
# Querying Data for pacific grove
# -----------------------------
# Appending Data for pacific grove
# Processing Record 34 of Set 4 | hilo
# -----------------------------
# Querying Data for hilo
# -----------------------------
# Appending Data for hilo
# Processing Record 35 of Set 4 | saint-georges
# -----------------------------
# Querying Data for saint-georges
# -----------------------------
# Appending Data for saint-georges
# Processing Record 36 of Set 4 | dakar
# -----------------------------
# Querying Data for dakar
# -----------------------------
# Appending Data for dakar
# Processing Record 37 of Set 4 | ostrovnoy
# -----------------------------
# Querying Data for ostrovnoy
# -----------------------------
# Appending Data for ostrovnoy
# Processing Record 38 of Set 4 | kavieng
# -----------------------------
# Querying Data for kavieng
# -----------------------------
# Appending Data for kavieng
# Processing Record 39 of Set 4 | sumenep
# -----------------------------
# Querying Data for sumenep
# -----------------------------
# Appending Data for sumenep
# Processing Record 40 of Set 4 | malwan
# -----------------------------
# Querying Data for malwan
# City not found. Skipping...
# Processing Record 41 of Set 4 | zeya
# -----------------------------
# Querying Data for zeya
# -----------------------------
# Appending Data for zeya
# Processing Record 42 of Set 4 | sibolga
# -----------------------------
# Querying Data for sibolga
# -----------------------------
# Appending Data for sibolga
# Processing Record 43 of Set 4 | yumen
# -----------------------------
# Querying Data for yumen
# -----------------------------
# Appending Data for yumen
# Processing Record 44 of Set 4 | onalaska
# -----------------------------
# Querying Data for onalaska
# -----------------------------
# Appending Data for onalaska
# Processing Record 45 of Set 4 | miri
# -----------------------------
# Querying Data for miri
# -----------------------------
# Appending Data for miri
# Processing Record 46 of Set 4 | mayo
# -----------------------------
# Querying Data for mayo
# -----------------------------
# Appending Data for mayo
# Processing Record 47 of Set 4 | lichtenburg
# -----------------------------
# Querying Data for lichtenburg
# -----------------------------
# Appending Data for lichtenburg
# Processing Record 48 of Set 4 | dalgopol
# -----------------------------
# Querying Data for dalgopol
# -----------------------------
# Appending Data for dalgopol
# Processing Record 49 of Set 4 | bela
# -----------------------------
# Querying Data for bela
# -----------------------------
# Appending Data for bela
# Processing Record 50 of Set 4 | victoria
# -----------------------------
# Querying Data for victoria
# -----------------------------
# Appending Data for victoria
# Processing Record 1 of Set 5 | khorixas
# -----------------------------
# Querying Data for khorixas
# -----------------------------
# Appending Data for khorixas
# Processing Record 2 of Set 5 | sataua
# -----------------------------
# Querying Data for sataua
# City not found. Skipping...
# Processing Record 3 of Set 5 | acapulco
# -----------------------------
# Querying Data for acapulco
# -----------------------------
# Appending Data for acapulco
# Processing Record 4 of Set 5 | real
# -----------------------------
# Querying Data for real
# -----------------------------
# Appending Data for real
# Processing Record 5 of Set 5 | leningradskiy
# -----------------------------
# Querying Data for leningradskiy
# -----------------------------
# Appending Data for leningradskiy
# Processing Record 6 of Set 5 | devils lake
# -----------------------------
# Querying Data for devils lake
# -----------------------------
# Appending Data for devils lake
# Processing Record 7 of Set 5 | san quintin
# -----------------------------
# Querying Data for san quintin
# -----------------------------
# Appending Data for san quintin
# Processing Record 8 of Set 5 | orlik
# -----------------------------
# Querying Data for orlik
# -----------------------------
# Appending Data for orlik
# Processing Record 9 of Set 5 | katsuura
# -----------------------------
# Querying Data for katsuura
# -----------------------------
# Appending Data for katsuura
# Processing Record 10 of Set 5 | cabo san lucas
# -----------------------------
# Querying Data for cabo san lucas
# -----------------------------
# Appending Data for cabo san lucas
# Processing Record 11 of Set 5 | thespiai
# -----------------------------
# Querying Data for thespiai
# City not found. Skipping...
# Processing Record 12 of Set 5 | tharad
# -----------------------------
# Querying Data for tharad
# -----------------------------
# Appending Data for tharad
# Processing Record 13 of Set 5 | krasnomayskiy
# -----------------------------
# Querying Data for krasnomayskiy
# -----------------------------
# Appending Data for krasnomayskiy
# Processing Record 14 of Set 5 | hay river
# -----------------------------
# Querying Data for hay river
# -----------------------------
# Appending Data for hay river
# Processing Record 15 of Set 5 | bossangoa
# -----------------------------
# Querying Data for bossangoa
# -----------------------------
# Appending Data for bossangoa
# Processing Record 16 of Set 5 | tomohon
# -----------------------------
# Querying Data for tomohon
# -----------------------------
# Appending Data for tomohon
# Processing Record 17 of Set 5 | lakes entrance
# -----------------------------
# Querying Data for lakes entrance
# -----------------------------
# Appending Data for lakes entrance
# Processing Record 18 of Set 5 | viedma
# -----------------------------
# Querying Data for viedma
# -----------------------------
# Appending Data for viedma
# Processing Record 19 of Set 5 | bambous virieux
# -----------------------------
# Querying Data for bambous virieux
# -----------------------------
# Appending Data for bambous virieux
# Processing Record 20 of Set 5 | yeniseysk
# -----------------------------
# Querying Data for yeniseysk
# -----------------------------
# Appending Data for yeniseysk
# Processing Record 21 of Set 5 | ilulissat
# -----------------------------
# Querying Data for ilulissat
# -----------------------------
# Appending Data for ilulissat
# Processing Record 22 of Set 5 | phalaborwa
# -----------------------------
# Querying Data for phalaborwa
# -----------------------------
# Appending Data for phalaborwa
# Processing Record 23 of Set 5 | alsfeld
# -----------------------------
# Querying Data for alsfeld
# -----------------------------
# Appending Data for alsfeld
# Processing Record 24 of Set 5 | mahebourg
# -----------------------------
# Querying Data for mahebourg
# -----------------------------
# Appending Data for mahebourg
# Processing Record 25 of Set 5 | hrymayliv
# -----------------------------
# Querying Data for hrymayliv
# -----------------------------
# Appending Data for hrymayliv
# Processing Record 26 of Set 5 | torbay
# -----------------------------
# Querying Data for torbay
# -----------------------------
# Appending Data for torbay
# Processing Record 27 of Set 5 | muyezerskiy
# -----------------------------
# Querying Data for muyezerskiy
# -----------------------------
# Appending Data for muyezerskiy
# Processing Record 28 of Set 5 | rawson
# -----------------------------
# Querying Data for rawson
# -----------------------------
# Appending Data for rawson
# Processing Record 29 of Set 5 | trat
# -----------------------------
# Querying Data for trat
# -----------------------------
# Appending Data for trat
# Processing Record 30 of Set 5 | stornoway
# -----------------------------
# Querying Data for stornoway
# -----------------------------
# Appending Data for stornoway
# Processing Record 31 of Set 5 | mayumba
# -----------------------------
# Querying Data for mayumba
# -----------------------------
# Appending Data for mayumba
# Processing Record 32 of Set 5 | port-de-paix
# -----------------------------
# Querying Data for port-de-paix
# City not found. Skipping...
# Processing Record 33 of Set 5 | ukiah
# -----------------------------
# Querying Data for ukiah
# -----------------------------
# Appending Data for ukiah
# Processing Record 34 of Set 5 | kharitonovo
# -----------------------------
# Querying Data for kharitonovo
# -----------------------------
# Appending Data for kharitonovo
# Processing Record 35 of Set 5 | saleaula
# -----------------------------
# Querying Data for saleaula
# City not found. Skipping...
# Processing Record 36 of Set 5 | srednekolymsk
# -----------------------------
# Querying Data for srednekolymsk
# -----------------------------
# Appending Data for srednekolymsk
# Processing Record 37 of Set 5 | bastrop
# -----------------------------
# Querying Data for bastrop
# -----------------------------
# Appending Data for bastrop
# Processing Record 38 of Set 5 | hermanus
# -----------------------------
# Querying Data for hermanus
# -----------------------------
# Appending Data for hermanus
# Processing Record 39 of Set 5 | mehamn
# -----------------------------
# Querying Data for mehamn
# -----------------------------
# Appending Data for mehamn
# Processing Record 40 of Set 5 | barawe
# -----------------------------
# Querying Data for barawe
# City not found. Skipping...
# Processing Record 41 of Set 5 | antalaha
# -----------------------------
# Querying Data for antalaha
# -----------------------------
# Appending Data for antalaha
# Processing Record 42 of Set 5 | roswell
# -----------------------------
# Querying Data for roswell
# -----------------------------
# Appending Data for roswell
# Processing Record 43 of Set 5 | muzhi
# -----------------------------
# Querying Data for muzhi
# -----------------------------
# Appending Data for muzhi
# Processing Record 44 of Set 5 | bria
# -----------------------------
# Querying Data for bria
# -----------------------------
# Appending Data for bria
# Processing Record 45 of Set 5 | oktyabrskoye
# -----------------------------
# Querying Data for oktyabrskoye
# -----------------------------
# Appending Data for oktyabrskoye
# Processing Record 46 of Set 5 | california city
# -----------------------------
# Querying Data for california city
# -----------------------------
# Appending Data for california city
# Processing Record 47 of Set 5 | broome
# -----------------------------
# Querying Data for broome
# -----------------------------
# Appending Data for broome
# Processing Record 48 of Set 5 | saquena
# -----------------------------
# Querying Data for saquena
# -----------------------------
# Appending Data for saquena
# Processing Record 49 of Set 5 | san policarpo
# -----------------------------
# Querying Data for san policarpo
# -----------------------------
# Appending Data for san policarpo
# Processing Record 50 of Set 5 | chuguyevka
# -----------------------------
# Querying Data for chuguyevka
# -----------------------------
# Appending Data for chuguyevka
# Processing Record 1 of Set 6 | alofi
# -----------------------------
# Querying Data for alofi
# -----------------------------
# Appending Data for alofi
# Processing Record 2 of Set 6 | gulshat
# -----------------------------
# Querying Data for gulshat
# City not found. Skipping...
# Processing Record 3 of Set 6 | collie
# -----------------------------
# Querying Data for collie
# -----------------------------
# Appending Data for collie
# Processing Record 4 of Set 6 | butaritari
# -----------------------------
# Querying Data for butaritari
# -----------------------------
# Appending Data for butaritari
# Processing Record 5 of Set 6 | calvia
# -----------------------------
# Querying Data for calvia
# -----------------------------
# Appending Data for calvia
# Processing Record 6 of Set 6 | codrington
# -----------------------------
# Querying Data for codrington
# -----------------------------
# Appending Data for codrington
# Processing Record 7 of Set 6 | kununurra
# -----------------------------
# Querying Data for kununurra
# -----------------------------
# Appending Data for kununurra
# Processing Record 8 of Set 6 | dingle
# -----------------------------
# Querying Data for dingle
# -----------------------------
# Appending Data for dingle
# Processing Record 9 of Set 6 | brumado
# -----------------------------
# Querying Data for brumado
# -----------------------------
# Appending Data for brumado
# Processing Record 10 of Set 6 | palabuhanratu
# -----------------------------
# Querying Data for palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 6 | awjilah
# -----------------------------
# Querying Data for awjilah
# -----------------------------
# Appending Data for awjilah
# Processing Record 12 of Set 6 | skjervoy
# -----------------------------
# Querying Data for skjervoy
# -----------------------------
# Appending Data for skjervoy
# Processing Record 13 of Set 6 | launceston
# -----------------------------
# Querying Data for launceston
# -----------------------------
# Appending Data for launceston
# Processing Record 14 of Set 6 | yulara
# -----------------------------
# Querying Data for yulara
# -----------------------------
# Appending Data for yulara
# Processing Record 15 of Set 6 | dudinka
# -----------------------------
# Querying Data for dudinka
# -----------------------------
# Appending Data for dudinka
# Processing Record 16 of Set 6 | mindelo
# -----------------------------
# Querying Data for mindelo
# -----------------------------
# Appending Data for mindelo
# Processing Record 17 of Set 6 | grindavik
# -----------------------------
# Querying Data for grindavik
# -----------------------------
# Appending Data for grindavik
# Processing Record 18 of Set 6 | manihari
# -----------------------------
# Querying Data for manihari
# -----------------------------
# Appending Data for manihari
# Processing Record 19 of Set 6 | faanui
# -----------------------------
# Querying Data for faanui
# -----------------------------
# Appending Data for faanui
# Processing Record 20 of Set 6 | labytnangi
# -----------------------------
# Querying Data for labytnangi
# -----------------------------
# Appending Data for labytnangi
# Processing Record 21 of Set 6 | eastchester
# -----------------------------
# Querying Data for eastchester
# -----------------------------
# Appending Data for eastchester
# Processing Record 22 of Set 6 | sedriano
# -----------------------------
# Querying Data for sedriano
# -----------------------------
# Appending Data for sedriano
# Processing Record 23 of Set 6 | weifang
# -----------------------------
# Querying Data for weifang
# -----------------------------
# Appending Data for weifang
# Processing Record 24 of Set 6 | blonduos
# -----------------------------
# Querying Data for blonduos
# City not found. Skipping...
# Processing Record 25 of Set 6 | cairns
# -----------------------------
# Querying Data for cairns
# -----------------------------
# Appending Data for cairns
# Processing Record 26 of Set 6 | beringovskiy
# -----------------------------
# Querying Data for beringovskiy
# -----------------------------
# Appending Data for beringovskiy
# Processing Record 27 of Set 6 | belushya guba
# -----------------------------
# Querying Data for belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 6 | chuy
# -----------------------------
# Querying Data for chuy
# -----------------------------
# Appending Data for chuy
# Processing Record 29 of Set 6 | maceio
# -----------------------------
# Querying Data for maceio
# -----------------------------
# Appending Data for maceio
# Processing Record 30 of Set 6 | sur
# -----------------------------
# Querying Data for sur
# -----------------------------
# Appending Data for sur
# Processing Record 31 of Set 6 | chongwe
# -----------------------------
# Querying Data for chongwe
# -----------------------------
# Appending Data for chongwe
# Processing Record 32 of Set 6 | katsiveli
# -----------------------------
# Querying Data for katsiveli
# City not found. Skipping...
# Processing Record 33 of Set 6 | san patricio
# -----------------------------
# Querying Data for san patricio
# -----------------------------
# Appending Data for san patricio
# Processing Record 34 of Set 6 | karratha
# -----------------------------
# Querying Data for karratha
# -----------------------------
# Appending Data for karratha
# Processing Record 35 of Set 6 | carballo
# -----------------------------
# Querying Data for carballo
# -----------------------------
# Appending Data for carballo
# Processing Record 36 of Set 6 | kanchanaburi
# -----------------------------
# Querying Data for kanchanaburi
# -----------------------------
# Appending Data for kanchanaburi
# Processing Record 37 of Set 6 | san cristobal
# -----------------------------
# Querying Data for san cristobal
# -----------------------------
# Appending Data for san cristobal
# Processing Record 38 of Set 6 | saurimo
# -----------------------------
# Querying Data for saurimo
# -----------------------------
# Appending Data for saurimo
# Processing Record 39 of Set 6 | mitikas
# -----------------------------
# Querying Data for mitikas
# -----------------------------
# Appending Data for mitikas
# Processing Record 40 of Set 6 | arrifes
# -----------------------------
# Querying Data for arrifes
# -----------------------------
# Appending Data for arrifes
# Processing Record 41 of Set 6 | havre-saint-pierre
# -----------------------------
# Querying Data for havre-saint-pierre
# -----------------------------
# Appending Data for havre-saint-pierre
# Processing Record 42 of Set 6 | kamuli
# -----------------------------
# Querying Data for kamuli
# -----------------------------
# Appending Data for kamuli
# Processing Record 43 of Set 6 | brae
# -----------------------------
# Querying Data for brae
# -----------------------------
# Appending Data for brae
# Processing Record 44 of Set 6 | rockland
# -----------------------------
# Querying Data for rockland
# -----------------------------
# Appending Data for rockland
# Processing Record 45 of Set 6 | indulang
# -----------------------------
# Querying Data for indulang
# -----------------------------
# Appending Data for indulang
# Processing Record 46 of Set 6 | christchurch
# -----------------------------
# Querying Data for christchurch
# -----------------------------
# Appending Data for christchurch
# Processing Record 47 of Set 6 | sibirtsevo
# -----------------------------
# Querying Data for sibirtsevo
# City not found. Skipping...
# Processing Record 48 of Set 6 | kidal
# -----------------------------
# Querying Data for kidal
# -----------------------------
# Appending Data for kidal
# Processing Record 49 of Set 6 | yerbogachen
# -----------------------------
# Querying Data for yerbogachen
# -----------------------------
# Appending Data for yerbogachen
# Processing Record 50 of Set 6 | grimshaw
# -----------------------------
# Querying Data for grimshaw
# -----------------------------
# Appending Data for grimshaw
# Processing Record 1 of Set 7 | inhambane
# -----------------------------
# Querying Data for inhambane
# -----------------------------
# Appending Data for inhambane
# Processing Record 2 of Set 7 | hovd
# -----------------------------
# Querying Data for hovd
# -----------------------------
# Appending Data for hovd
# Processing Record 3 of Set 7 | esmeraldas
# -----------------------------
# Querying Data for esmeraldas
# -----------------------------
# Appending Data for esmeraldas
# Processing Record 4 of Set 7 | moundsville
# -----------------------------
# Querying Data for moundsville
# -----------------------------
# Appending Data for moundsville
# Processing Record 5 of Set 7 | arraial do cabo
# -----------------------------
# Querying Data for arraial do cabo
# -----------------------------
# Appending Data for arraial do cabo
# Processing Record 6 of Set 7 | meulaboh
# -----------------------------
# Querying Data for meulaboh
# -----------------------------
# Appending Data for meulaboh
# Processing Record 7 of Set 7 | kisangani
# -----------------------------
# Querying Data for kisangani
# -----------------------------
# Appending Data for kisangani
# Processing Record 8 of Set 7 | balao
# -----------------------------
# Querying Data for balao
# -----------------------------
# Appending Data for balao
# Processing Record 9 of Set 7 | statesboro
# -----------------------------
# Querying Data for statesboro
# -----------------------------
# Appending Data for statesboro
# Processing Record 10 of Set 7 | fallon
# -----------------------------
# Querying Data for fallon
# -----------------------------
# Appending Data for fallon
# Processing Record 11 of Set 7 | dasoguz
# -----------------------------
# Querying Data for dasoguz
# ...
# Querying Data for klaksvik
# -----------------------------
# Appending Data for klaksvik
# Processing Record 28 of Set 14 | russell
# -----------------------------
# Querying Data for russell
# -----------------------------
# Appending Data for russell
# Processing Record 29 of Set 14 | poum
# -----------------------------
# Querying Data for poum
# -----------------------------
# Appending Data for poum
# Processing Record 30 of Set 14 | liberty
# -----------------------------
# Querying Data for liberty
# -----------------------------
# Appending Data for liberty
# Processing Record 31 of Set 14 | pulivendla
# -----------------------------
# Querying Data for pulivendla
# -----------------------------
# Appending Data for pulivendla
# Processing Record 32 of Set 14 | ulaangom
# -----------------------------
# Querying Data for ulaangom
# -----------------------------
# Appending Data for ulaangom
# Processing Record 33 of Set 14 | omaha
# -----------------------------
# Querying Data for omaha
# -----------------------------
# Appending Data for omaha
# Processing Record 34 of Set 14 | kindu
# -----------------------------
# Querying Data for kindu
# -----------------------------
# Appending Data for kindu
# Processing Record 35 of Set 14 | bonthe
# -----------------------------
# Querying Data for bonthe
# -----------------------------
# Appending Data for bonthe
# Processing Record 36 of Set 14 | bayugan
# -----------------------------
# Querying Data for bayugan
# -----------------------------
# Appending Data for bayugan
# Processing Record 37 of Set 14 | auckland
# -----------------------------
# Querying Data for auckland
# -----------------------------
# Appending Data for auckland
# Processing Record 38 of Set 14 | lovozero
# -----------------------------
# Querying Data for lovozero
# -----------------------------
# Appending Data for lovozero
# Processing Record 39 of Set 14 | galiwinku
# -----------------------------
# Querying Data for galiwinku
# City not found. Skipping...
# Processing Record 40 of Set 14 | anda
# -----------------------------
# Querying Data for anda
# -----------------------------
# Appending Data for anda
# Processing Record 41 of Set 14 | pueblo
# -----------------------------
# Querying Data for pueblo
# -----------------------------
# Appending Data for pueblo
# Processing Record 42 of Set 14 | kharabali
# -----------------------------
# Querying Data for kharabali
# -----------------------------
# Appending Data for kharabali
# Processing Record 43 of Set 14 | waipawa
# -----------------------------
# Querying Data for waipawa
# -----------------------------
# Appending Data for waipawa
# Processing Record 44 of Set 14 | isangel
# -----------------------------
# Querying Data for isangel
# -----------------------------
# Appending Data for isangel
# Processing Record 45 of Set 14 | balykshi
# -----------------------------
# Querying Data for balykshi
# -----------------------------
# Appending Data for balykshi
# Processing Record 46 of Set 14 | sargatskoye
# -----------------------------
# Querying Data for sargatskoye
# -----------------------------
# Appending Data for sargatskoye
# Processing Record 47 of Set 14 | sarangani
# -----------------------------
# Querying Data for sarangani
# -----------------------------
# Appending Data for sarangani
# Processing Record 48 of Set 14 | artigas
# -----------------------------
# Querying Data for artigas
# -----------------------------
# Appending Data for artigas
# Processing Record 49 of Set 14 | portpatrick
# -----------------------------
# Querying Data for portpatrick
# City not found. Skipping...
# Processing Record 50 of Set 14 | minab
# -----------------------------
# Querying Data for minab
# -----------------------------
# Appending Data for minab
# Processing Record 1 of Set 15 | voh
# -----------------------------
# Querying Data for voh
# -----------------------------
# Appending Data for voh
# Processing Record 2 of Set 15 | nhamunda
# -----------------------------
# Querying Data for nhamunda
# -----------------------------
# Appending Data for nhamunda
# Processing Record 3 of Set 15 | fundacion
# -----------------------------
# Querying Data for fundacion
# -----------------------------
# Appending Data for fundacion
# Processing Record 4 of Set 15 | burnie
# -----------------------------
# Querying Data for burnie
# -----------------------------
# Appending Data for burnie
# Processing Record 5 of Set 15 | setermoen
# -----------------------------
# Querying Data for setermoen
# -----------------------------
# Appending Data for setermoen
# Processing Record 6 of Set 15 | jieshi
# -----------------------------
# Querying Data for jieshi
# -----------------------------
# Appending Data for jieshi
# Processing Record 7 of Set 15 | grootfontein
# -----------------------------
# Querying Data for grootfontein
# -----------------------------
# Appending Data for grootfontein
# Processing Record 8 of Set 15 | venice
# -----------------------------
# Querying Data for venice
# -----------------------------
# Appending Data for venice
# Processing Record 9 of Set 15 | bourail
# -----------------------------
# Querying Data for bourail
# -----------------------------
# Appending Data for bourail
# Processing Record 10 of Set 15 | iracoubo
# -----------------------------
# Querying Data for iracoubo
# -----------------------------
# Appending Data for iracoubo
# Processing Record 11 of Set 15 | taltal
# -----------------------------
# Querying Data for taltal
# -----------------------------
# Appending Data for taltal
# Processing Record 12 of Set 15 | manoel urbano
# -----------------------------
# Querying Data for manoel urbano
# -----------------------------
# Appending Data for manoel urbano
# Processing Record 13 of Set 15 | la ronge
# -----------------------------
# Querying Data for la ronge
# -----------------------------
# Appending Data for la ronge
# Processing Record 14 of Set 15 | novaya igirma
# -----------------------------
# Querying Data for novaya igirma
# -----------------------------
# Appending Data for novaya igirma
# Processing Record 15 of Set 15 | horn
# -----------------------------
# Querying Data for horn
# -----------------------------
# Appending Data for horn
# Processing Record 16 of Set 15 | mirabad
# -----------------------------
# Querying Data for mirabad
# -----------------------------
# Appending Data for mirabad
# Processing Record 17 of Set 15 | khilok
# -----------------------------
# Querying Data for khilok
# -----------------------------
# Appending Data for khilok
# Processing Record 18 of Set 15 | hervey bay
# -----------------------------
# Querying Data for hervey bay
# -----------------------------
# Appending Data for hervey bay
# Processing Record 19 of Set 15 | beaverlodge
# -----------------------------
# Querying Data for beaverlodge
# -----------------------------
# Appending Data for beaverlodge
# Processing Record 20 of Set 15 | marsh harbour
# -----------------------------
# Querying Data for marsh harbour
# -----------------------------
# Appending Data for marsh harbour
# Processing Record 21 of Set 15 | ocampo
# -----------------------------
# Querying Data for ocampo
# -----------------------------
# Appending Data for ocampo
# Processing Record 22 of Set 15 | dauphin
# -----------------------------
# Querying Data for dauphin
# -----------------------------
# Appending Data for dauphin
# Processing Record 23 of Set 15 | megion
# -----------------------------
# Querying Data for megion
# -----------------------------
# Appending Data for megion
# Processing Record 24 of Set 15 | cuamba
# -----------------------------
# Querying Data for cuamba
# -----------------------------
# Appending Data for cuamba
# Processing Record 25 of Set 15 | urdzhar
# -----------------------------
# Querying Data for urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 15 | tiarei
# -----------------------------
# Querying Data for tiarei
# -----------------------------
# Appending Data for tiarei
# Processing Record 27 of Set 15 | leninskoye
# -----------------------------
# Querying Data for leninskoye
# -----------------------------
# Appending Data for leninskoye
# Processing Record 28 of Set 15 | ituni
# -----------------------------
# Querying Data for ituni
# City not found. Skipping...
# Processing Record 29 of Set 15 | maniitsoq
# -----------------------------
# Querying Data for maniitsoq
# -----------------------------
# Appending Data for maniitsoq
# Processing Record 30 of Set 15 | ust-nera
# -----------------------------
# Querying Data for ust-nera
# -----------------------------
# Appending Data for ust-nera
# Processing Record 31 of Set 15 | dumbravita
# -----------------------------
# Querying Data for dumbravita
# -----------------------------
# Appending Data for dumbravita
# Processing Record 32 of Set 15 | teknaf
# -----------------------------
# Querying Data for teknaf
# -----------------------------
# Appending Data for teknaf
# Processing Record 33 of Set 15 | ugoofaaru
# -----------------------------
# Querying Data for ugoofaaru
# -----------------------------
# Appending Data for ugoofaaru
# Processing Record 34 of Set 15 | karaton
# -----------------------------
# Querying Data for karaton
# -----------------------------
# Appending Data for karaton
# Processing Record 35 of Set 15 | malumfashi
# -----------------------------
# Querying Data for malumfashi
# -----------------------------
# Appending Data for malumfashi
# Processing Record 36 of Set 15 | port-gentil
# -----------------------------
# Querying Data for port-gentil
# -----------------------------
# Appending Data for port-gentil
# Processing Record 37 of Set 15 | puerto wilches
# -----------------------------
# Querying Data for puerto wilches
# -----------------------------
# Appending Data for puerto wilches
# Processing Record 38 of Set 15 | puerto colombia
# -----------------------------
# Querying Data for puerto colombia
# -----------------------------
# Appending Data for puerto colombia
# Processing Record 39 of Set 15 | cravo norte
# -----------------------------
# Querying Data for cravo norte
# -----------------------------
# Appending Data for cravo norte
# Processing Record 40 of Set 15 | miles city
# -----------------------------
# Querying Data for miles city
# -----------------------------
# Appending Data for miles city
# Processing Record 41 of Set 15 | tartagal
# -----------------------------
# Querying Data for tartagal
# -----------------------------
# Appending Data for tartagal
# Processing Record 42 of Set 15 | palana
# -----------------------------
# Querying Data for palana
# -----------------------------
# Appending Data for palana
# Processing Record 43 of Set 15 | shellbrook
# -----------------------------
# Querying Data for shellbrook
# -----------------------------
# Appending Data for shellbrook
# Processing Record 44 of Set 15 | mikuni
# -----------------------------
# Querying Data for mikuni
# -----------------------------
# Appending Data for mikuni
# Processing Record 45 of Set 15 | santiago del estero
# -----------------------------
# Querying Data for santiago del estero
# -----------------------------
# Appending Data for santiago del estero
# Processing Record 46 of Set 15 | hunza
# -----------------------------
# Querying Data for hunza
# City not found. Skipping...
# Processing Record 47 of Set 15 | karachi
# -----------------------------
# Querying Data for karachi
# -----------------------------
# Appending Data for karachi
# Processing Record 48 of Set 15 | balkanabat
# -----------------------------
# Querying Data for balkanabat
# -----------------------------
# Appending Data for balkanabat
# Processing Record 49 of Set 15 | chillan
# -----------------------------
# Querying Data for chillan
# -----------------------------
# Appending Data for chillan
# Processing Record 50 of Set 15 | katete
# -----------------------------
# Querying Data for katete
# -----------------------------
# Appending Data for katete
# Processing Record 1 of Set 16 | road town
# -----------------------------
# Querying Data for road town
# -----------------------------
# Appending Data for road town
# Processing Record 2 of Set 16 | phayao
# -----------------------------
# Querying Data for phayao
# -----------------------------
# Appending Data for phayao
# Processing Record 3 of Set 16 | mission bend
# -----------------------------
# Querying Data for mission bend
# -----------------------------
# Appending Data for mission bend
# Processing Record 4 of Set 16 | matara
# -----------------------------
# Querying Data for matara
# -----------------------------
# Appending Data for matara
# Processing Record 5 of Set 16 | hami
# -----------------------------
# Querying Data for hami
# -----------------------------
# Appending Data for hami
# Processing Record 6 of Set 16 | tyshkivka
# -----------------------------
# Querying Data for tyshkivka
# -----------------------------
# Appending Data for tyshkivka
# Processing Record 7 of Set 16 | mareeba
# -----------------------------
# Querying Data for mareeba
# -----------------------------
# Appending Data for mareeba
# Processing Record 8 of Set 16 | kalaleh
# -----------------------------
# Querying Data for kalaleh
# -----------------------------
# Appending Data for kalaleh
# Processing Record 9 of Set 16 | agadez
# -----------------------------
# Querying Data for agadez
# -----------------------------
# Appending Data for agadez
# Processing Record 10 of Set 16 | parras
# -----------------------------
# Querying Data for parras
# City not found. Skipping...
# Processing Record 11 of Set 16 | mutsamudu
# -----------------------------
# Querying Data for mutsamudu
# City not found. Skipping...
# Processing Record 12 of Set 16 | micheweni
# -----------------------------
# Querying Data for micheweni
# -----------------------------
# Appending Data for micheweni
# Processing Record 13 of Set 16 | kahului
# -----------------------------
# Querying Data for kahului
# -----------------------------
# Appending Data for kahului
# Processing Record 14 of Set 16 | miguel hidalgo
# -----------------------------
# Querying Data for miguel hidalgo
# -----------------------------
# Appending Data for miguel hidalgo
# Processing Record 15 of Set 16 | langxiang
# -----------------------------
# Querying Data for langxiang
# -----------------------------
# Appending Data for langxiang
# Processing Record 16 of Set 16 | prado
# -----------------------------
# Querying Data for prado
# -----------------------------
# Appending Data for prado
# Processing Record 17 of Set 16 | bukama
# -----------------------------
# Querying Data for bukama
# -----------------------------
# Appending Data for bukama
# Processing Record 18 of Set 16 | san-pedro
# -----------------------------
# Querying Data for san-pedro
# -----------------------------
# Appending Data for san-pedro
# Processing Record 19 of Set 16 | sovetskaya gavan
# -----------------------------
# Querying Data for sovetskaya gavan
# -----------------------------
# Appending Data for sovetskaya gavan
# Processing Record 20 of Set 16 | uk
# -----------------------------
# Querying Data for uk
# City not found. Skipping...
# Processing Record 21 of Set 16 | te anau
# -----------------------------
# Querying Data for te anau
# -----------------------------
# Appending Data for te anau
# Processing Record 22 of Set 16 | kupang
# -----------------------------
# Querying Data for kupang
# -----------------------------
# Appending Data for kupang
# Processing Record 23 of Set 16 | zhicheng
# -----------------------------
# Querying Data for zhicheng
# -----------------------------
# Appending Data for zhicheng
# Processing Record 24 of Set 16 | morant bay
# -----------------------------
# Querying Data for morant bay
# -----------------------------
# Appending Data for morant bay
# Processing Record 25 of Set 16 | uribia
# -----------------------------
# Querying Data for uribia
# -----------------------------
# Appending Data for uribia
# Processing Record 26 of Set 16 | stryn
# -----------------------------
# Querying Data for stryn
# -----------------------------
# Appending Data for stryn
# Processing Record 27 of Set 16 | lomas de sargentillo
# -----------------------------
# Querying Data for lomas de sargentillo
# -----------------------------
# Appending Data for lomas de sargentillo
# Processing Record 28 of Set 16 | qaracala
# -----------------------------
# Querying Data for qaracala
# -----------------------------
# Appending Data for qaracala
# Processing Record 29 of Set 16 | basirhat
# -----------------------------
# Querying Data for basirhat
# -----------------------------
# Appending Data for basirhat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Santona',
#   'Country': 'ES',
#   'Lat': 43.4439,
#   'Lng': -3.4576,
#   'Max Temp': 22.17,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 3.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 27.8,
#   'Humidity': 71,
#   'Cloudiness': 76,
#   'Wind Speed': 1.18,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chernyshevskiy',
#   'Country': 'RU',
#   'Lat': 63.0128,
#   'Lng': 112.4714,
#   'Max Temp': 8.94,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 2.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tadine',
#   'Country': 'NC',
#   'Lat': -21.55,
#   'Lng': 167.8833,
#   'Max Temp': 23.47,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 8.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Praxedis Guerrero',
#   'Country': 'MX',
#   'Lat': 31.3667,
#   'Lng': -106.0167,
#   'Max Temp': 31.72,
#   'Humidity': 26,
#   'Cloudiness': 44,
#   'Wind Speed': 1.13,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 29.96,
#   'Humidity': 85,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Current Description': 'few clouds'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 9.26,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 17,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 2.14,
#   'Current Description': 'clear sky'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 12.18,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 24.03,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cockburn Town',
#   'Country': 'TC',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 27.66,
#   'Humidity': 79,
#   'Cloudiness': 16,
#   'Wind Speed': 5.95,
#   'Current Description': 'few clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 18.8,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Current Description': 'clear sky'},
#  {'City': 'Keroka',
#   'Country': 'KE',
#   'Lat': -0.7758,
#   'Lng': 34.9453,
#   'Max Temp': 12.38,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 2.01,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Current Description': 'mist'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 11.41,
#   'Humidity': 68,
#   'Cloudiness': 21,
#   'Wind Speed': 2.9,
#   'Current Description': 'few clouds'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 12.91,
#   'Humidity': 62,
#   'Cloudiness': 79,
#   'Wind Speed': 7.92,
#   'Current Description': 'broken clouds'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 23.08,
#   'Humidity': 80,
#   'Cloudiness': 83,
#   'Wind Speed': 9.1,
#   'Current Description': 'broken clouds'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 14.25,
#   'Humidity': 63,
#   'Cloudiness': 23,
#   'Wind Speed': 2.29,
#   'Current Description': 'few clouds'},
#  {'City': 'Acajutla',
#   'Country': 'SV',
#   'Lat': 13.5928,
#   'Lng': -89.8275,
#   'Max Temp': 26.74,
#   'Humidity': 82,
#   'Cloudiness': 81,
#   'Wind Speed': 2.11,
#   'Current Description': 'broken clouds'},
#  {'City': 'Broken Hill',
#   'Country': 'AU',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 13.95,
#   'Humidity': 50,
#   'Cloudiness': 23,
#   'Wind Speed': 7.24,
#   'Current Description': 'few clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 11.56,
#   'Humidity': 49,
#   'Cloudiness': 68,
#   'Wind Speed': 2.7,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hualmay',
#   'Country': 'PE',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 16.51,
#   'Humidity': 83,
#   'Cloudiness': 38,
#   'Wind Speed': 4.04,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Beian',
#   'Country': 'NO',
#   'Lat': 63.6559,
#   'Lng': 9.5683,
#   'Max Temp': 13.34,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 13.94,
#   'Humidity': 70,
#   'Cloudiness': 3,
#   'Wind Speed': 10.28,
#   'Current Description': 'light rain'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 2.84,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 20.27,
#   'Humidity': 75,
#   'Cloudiness': 6,
#   'Wind Speed': 1.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Bathsheba',
#   'Country': 'BB',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 27.21,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 3.69,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Erzin',
#   'Country': 'TR',
#   'Lat': 36.9559,
#   'Lng': 36.2,
#   'Max Temp': 24.28,
#   'Humidity': 87,
#   'Cloudiness': 69,
#   'Wind Speed': 1.26,
#   'Current Description': 'broken clouds'},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 23.93,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 7.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 2.81,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 7.72,
#   'Current Description': 'broken clouds'},
#  {'City': 'Juneau',
#   'Country': 'US',
#   'Lat': 58.3019,
#   'Lng': -134.4197,
#   'Max Temp': 16.79,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 2.25,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Porto Novo',
#   'Country': 'BJ',
#   'Lat': 6.4965,
#   'Lng': 2.6036,
#   'Max Temp': 23.37,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.93,
#   'Current Description': 'light rain'},
#  {'City': 'Lhokseumawe',
#   'Country': 'ID',
#   'Lat': 5.1801,
#   'Lng': 97.1507,
#   'Max Temp': 26.64,
#   'Humidity': 82,
#   'Cloudiness': 96,
#   'Wind Speed': 1.12,
#   'Current Description': 'moderate rain'},
#  {'City': 'Gwadar',
#   'Country': 'PK',
#   'Lat': 25.1216,
#   'Lng': 62.3254,
#   'Max Temp': 28.11,
#   'Humidity': 84,
#   'Cloudiness': 67,
#   'Wind Speed': 4.11,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 10.06,
#   'Humidity': 84,
#   'Cloudiness': 60,
#   'Wind Speed': 7.42,
#   'Current Description': 'light rain'},
#  {'City': 'Charters Towers',
#   'Country': 'AU',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 22.69,
#   'Humidity': 24,
#   'Cloudiness': 3,
#   'Wind Speed': 3.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 1.26,
#   'Humidity': 80,
#   'Cloudiness': 12,
#   'Wind Speed': 4.46,
#   'Current Description': 'few clouds'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 11.79,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 1.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Anadyr',
#   'Country': 'RU',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 10,
#   'Humidity': 61,
#   'Cloudiness': 73,
#   'Wind Speed': 4.92,
#   'Current Description': 'broken clouds'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 20.21,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 7.2,
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Hedland',
#   'Country': 'AU',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 29.03,
#   'Humidity': 30,
#   'Cloudiness': 8,
#   'Wind Speed': 4.63,
#   'Current Description': 'clear sky'},
#  {'City': 'Zabol',
#   'Country': 'AF',
#   'Lat': 32.25,
#   'Lng': 67.25,
#   'Max Temp': 23.88,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 3.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 8.82,
#   'Humidity': 78,
#   'Cloudiness': 11,
#   'Wind Speed': 6.64,
#   'Current Description': 'few clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 21.7,
#   'Humidity': 61,
#   'Cloudiness': 95,
#   'Wind Speed': 9.64,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 12.37,
#   'Humidity': 97,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vestmanna',
#   'Country': 'FO',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 9.51,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Current Description': 'light rain'},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 20.05,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 4.63,
#   'Current Description': 'few clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 19.08,
#   'Humidity': 69,
#   'Cloudiness': 56,
#   'Wind Speed': 1.48,
#   'Current Description': 'broken clouds'},
#  {'City': 'Teya',
#   'Country': 'RU',
#   'Lat': 60.3778,
#   'Lng': 92.6267,
#   'Max Temp': 16,
#   'Humidity': 54,
#   'Cloudiness': 99,
#   'Wind Speed': 1.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Olafsvik',
#   'Country': 'IS',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 8.98,
#   'Humidity': 76,
#   'Cloudiness': 44,
#   'Wind Speed': 1.73,
#   'Current Description': 'light rain'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 6.93,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dongying',
#   'Country': 'CN',
#   'Lat': 37.4564,
#   'Lng': 118.4856,
#   'Max Temp': 27.84,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kamenka',
#   'Country': 'RU',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 19.22,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 3.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 4.09,
#   'Humidity': 65,
#   'Cloudiness': 2,
#   'Wind Speed': 2.69,
#   'Current Description': 'clear sky'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 10.86,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 5.2,
#   'Current Description': 'clear sky'},
#  {'City': 'Williamsport',
#   'Country': 'US',
#   'Lat': 41.2412,
#   'Lng': -77.0011,
#   'Max Temp': 19.03,
#   'Humidity': 69,
#   'Cloudiness': 26,
#   'Wind Speed': 0.98,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 12.99,
#   'Humidity': 81,
#   'Cloudiness': 42,
#   'Wind Speed': 2.24,
#   'Current Description': 'light rain'},
#  {'City': 'Pandan',
#   'Country': 'PH',
#   'Lat': 14.0453,
#   'Lng': 124.1694,
#   'Max Temp': 30.82,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 1.06,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ribnitz-Damgarten',
#   'Country': 'DE',
#   'Lat': 54.25,
#   'Lng': 12.4667,
#   'Max Temp': 20.62,
#   'Humidity': 81,
#   'Cloudiness': 84,
#   'Wind Speed': 3.48,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 12.27,
#   'Humidity': 87,
#   'Cloudiness': 86,
#   'Wind Speed': 1.27,
#   'Current Description': 'light rain'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 28.99,
#   'Humidity': 71,
#   'Cloudiness': 45,
#   'Wind Speed': 2.24,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 8.12,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.37,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Francois',
#   'Country': 'FR',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 16.69,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Current Description': 'clear sky'},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 23.88,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 30.16,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 6.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 20.31,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kokoda',
#   'Country': 'PG',
#   'Lat': -8.8785,
#   'Lng': 147.7407,
#   'Max Temp': 31,
#   'Humidity': 59,
#   'Cloudiness': 96,
#   'Wind Speed': 2.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Giyani',
#   'Country': 'ZA',
#   'Lat': -23.3025,
#   'Lng': 30.7187,
#   'Max Temp': 18.68,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 1.84,
#   'Current Description': 'clear sky'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 7,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nuuk',
#   'Country': 'GL',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 9.34,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vestmannaeyjar',
#   'Country': 'IS',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 9.13,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 0.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coihaique',
#   'Country': 'CL',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 1.34,
#   'Humidity': 92,
#   'Cloudiness': 95,
#   'Wind Speed': 3.28,
#   'Current Description': 'light snow'},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 24.13,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 5.07,
#   'Current Description': 'light rain'},
#  {'City': 'Luanda',
#   'Country': 'AO',
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp': 19.39,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 0.33,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 12.12,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 4.28,
#   'Current Description': 'clear sky'},
#  {'City': 'Faya',
#   'Country': 'SA',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 19.15,
#   'Humidity': 80,
#   'Cloudiness': 94,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Lincoln',
#   'Country': 'AU',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 14.26,
#   'Humidity': 69,
#   'Cloudiness': 77,
#   'Wind Speed': 4.72,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vilhena',
#   'Country': 'BR',
#   'Lat': -12.7406,
#   'Lng': -60.1458,
#   'Max Temp': 21.27,
#   'Humidity': 48,
#   'Cloudiness': 7,
#   'Wind Speed': 0.48,
#   'Current Description': 'clear sky'},
#  {'City': 'Morgan City',
#   'Country': 'US',
#   'Lat': 29.6994,
#   'Lng': -91.2068,
#   'Max Temp': 25.56,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.19,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Roma',
#   'Country': 'US',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp': 17.02,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 19.48,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 3.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Ayan',
#   'Country': 'RU',
#   'Lat': 56.45,
#   'Lng': 138.1667,
#   'Max Temp': 14.2,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Korla',
#   'Country': 'CN',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 27.74,
#   'Humidity': 29,
#   'Cloudiness': 67,
#   'Wind Speed': 4.56,
#   'Current Description': 'broken clouds'},
#  {'City': 'Constitucion',
#   'Country': 'CL',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 10.59,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.71,
#   'Current Description': 'light rain'},
#  {'City': 'Koroni',
#   'Country': 'GR',
#   'Lat': 36.8,
#   'Lng': 21.95,
#   'Max Temp': 24.48,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 5.18,
#   'Current Description': 'clear sky'},
#  {'City': 'Laguna',
#   'Country': 'US',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 36.84,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Current Description': 'clear sky'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 22.35,
#   'Humidity': 77,
#   'Cloudiness': 21,
#   'Wind Speed': 1.34,
#   'Current Description': 'few clouds'},
#  {'City': 'Kargopol',
#   'Country': 'RU',
#   'Lat': 61.5071,
#   'Lng': 38.9456,
#   'Max Temp': 9.03,
#   'Humidity': 84,
#   'Cloudiness': 26,
#   'Wind Speed': 0.24,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mehndawal',
#   'Country': 'IN',
#   'Lat': 26.9753,
#   'Lng': 83.1117,
#   'Max Temp': 27.14,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 6.25,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chumikan',
#   'Country': 'RU',
#   'Lat': 54.7183,
#   'Lng': 135.315,
#   'Max Temp': 17.07,
#   'Humidity': 70,
#   'Cloudiness': 77,
#   'Wind Speed': 0.63,
#   'Current Description': 'broken clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 14.97,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 5.9,
#   'Current Description': 'clear sky'},
#  {'City': 'Gamba',
#   'Country': 'GA',
#   'Lat': -2.65,
#   'Lng': 10,
#   'Max Temp': 21.55,
#   'Humidity': 82,
#   'Cloudiness': 94,
#   'Wind Speed': 1.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jumla',
#   'Country': 'NP',
#   'Lat': 29.2747,
#   'Lng': 82.1838,
#   'Max Temp': 19.14,
#   'Humidity': 83,
#   'Cloudiness': 96,
#   'Wind Speed': 0.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Juan',
#   'Country': 'AR',
#   'Lat': -31.5375,
#   'Lng': -68.5364,
#   'Max Temp': 15.58,
#   'Humidity': 22,
#   'Cloudiness': 2,
#   'Wind Speed': 0.39,
#   'Current Description': 'clear sky'},
#  {'City': 'Inta',
#   'Country': 'RU',
#   'Lat': 66.0317,
#   'Lng': 60.1659,
#   'Max Temp': 6.99,
#   'Humidity': 90,
#   'Cloudiness': 93,
#   'Wind Speed': 6.12,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ancud',
#   'Country': 'CL',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 7.43,
#   'Humidity': 80,
#   'Cloudiness': 6,
#   'Wind Speed': 9.77,
#   'Current Description': 'light rain'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 22.91,
#   'Humidity': 85,
#   'Cloudiness': 20,
#   'Wind Speed': 6.82,
#   'Current Description': 'few clouds'},
#  {'City': 'Rosita',
#   'Country': 'NI',
#   'Lat': 13.9268,
#   'Lng': -84.4032,
#   'Max Temp': 23.84,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Martapura',
#   'Country': 'ID',
#   'Lat': -3.4167,
#   'Lng': 114.85,
#   'Max Temp': 27.05,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 2.57,
#   'Current Description': 'few clouds'},
#  {'City': 'Davlekanovo',
#   'Country': 'RU',
#   'Lat': 54.2215,
#   'Lng': 55.0343,
#   'Max Temp': 14.27,
#   'Humidity': 72,
#   'Cloudiness': 74,
#   'Wind Speed': 2.57,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jiuquan',
#   'Country': 'CN',
#   'Lat': 39.7432,
#   'Lng': 98.5174,
#   'Max Temp': 22.14,
#   'Humidity': 28,
#   'Cloudiness': 100,
#   'Wind Speed': 3.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 32.57,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Current Description': 'clear sky'},
#  {'City': 'Kharp',
#   'Country': 'RU',
#   'Lat': 66.8014,
#   'Lng': 65.8081,
#   'Max Temp': 7.86,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Andres',
#   'Country': 'CO',
#   'Lat': 12.5847,
#   'Lng': -81.7006,
#   'Max Temp': 28.01,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 2.57,
#   'Current Description': 'few clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 15.45,
#   'Humidity': 72,
#   'Cloudiness': 84,
#   'Wind Speed': 1.54,
#   'Current Description': 'broken clouds'},
#  {'City': 'Champerico',
#   'Country': 'GT',
#   'Lat': 14.3,
#   'Lng': -91.9167,
#   'Max Temp': 27.45,
#   'Humidity': 73,
#   'Cloudiness': 81,
#   'Wind Speed': 1.9,
#   'Current Description': 'broken clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 7.32,
#   'Humidity': 67,
#   'Cloudiness': 90,
#   'Wind Speed': 1.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 24.3,
#   'Humidity': 88,
#   'Cloudiness': 5,
#   'Wind Speed': 2.57,
#   'Current Description': 'clear sky'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 25.24,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 9.04,
#   'Current Description': 'clear sky'},
#  {'City': 'Los Llanos De Aridane',
#   'Country': 'ES',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 19.86,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Current Description': 'clear sky'},
#  {'City': 'Tuma',
#   'Country': 'RU',
#   'Lat': 55.148,
#   'Lng': 40.5537,
#   'Max Temp': 16.42,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 1.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lata',
#   'Country': 'PT',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 13.47,
#   'Humidity': 98,
#   'Cloudiness': 90,
#   'Wind Speed': 0.69,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 6.76,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 5.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Antofagasta',
#   'Country': 'CL',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 13.05,
#   'Humidity': 85,
#   'Cloudiness': 86,
#   'Wind Speed': 1.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 10.27,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 2.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Sechura',
#   'Country': 'PE',
#   'Lat': -5.5569,
#   'Lng': -80.8222,
#   'Max Temp': 17.24,
#   'Humidity': 84,
#   'Cloudiness': 5,
#   'Wind Speed': 6.63,
#   'Current Description': 'clear sky'},
#  {'City': 'Caxito',
#   'Country': 'AO',
#   'Lat': -8.5785,
#   'Lng': 13.6643,
#   'Max Temp': 18.46,
#   'Humidity': 94,
#   'Cloudiness': 80,
#   'Wind Speed': 0.77,
#   'Current Description': 'broken clouds'},
#  {'City': 'Huilong',
#   'Country': 'CN',
#   'Lat': 31.8111,
#   'Lng': 121.655,
#   'Max Temp': 31.53,
#   'Humidity': 67,
#   'Cloudiness': 70,
#   'Wind Speed': 4.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'Labuhan',
#   'Country': 'ID',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 28.28,
#   'Humidity': 71,
#   'Cloudiness': 99,
#   'Wind Speed': 3.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barkhan',
#   'Country': 'PK',
#   'Lat': 29.8977,
#   'Lng': 69.5256,
#   'Max Temp': 25.69,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 4.65,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Tual',
#   'Country': 'ID',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 26.74,
#   'Humidity': 78,
#   'Cloudiness': 76,
#   'Wind Speed': 9.1,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 7.59,
#   'Humidity': 62,
#   'Cloudiness': 61,
#   'Wind Speed': 4,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 19.07,
#   'Humidity': 52,
#   'Cloudiness': 14,
#   'Wind Speed': 3.04,
#   'Current Description': 'few clouds'},
#  {'City': 'Joao Pinheiro',
#   'Country': 'BR',
#   'Lat': -17.7425,
#   'Lng': -46.1725,
#   'Max Temp': 19.45,
#   'Humidity': 50,
#   'Cloudiness': 21,
#   'Wind Speed': 2.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 5.17,
#   'Humidity': 86,
#   'Cloudiness': 95,
#   'Wind Speed': 7.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 24.08,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 6.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Tabou',
#   'Country': 'CI',
#   'Lat': 4.423,
#   'Lng': -7.3528,
#   'Max Temp': 23.75,
#   'Humidity': 85,
#   'Cloudiness': 39,
#   'Wind Speed': 4.65,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 27.04,
#   'Humidity': 73,
#   'Cloudiness': 89,
#   'Wind Speed': 1.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 17.34,
#   'Humidity': 80,
#   'Cloudiness': 35,
#   'Wind Speed': 6.91,
#   'Current Description': 'light rain'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 4.85,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.54,
#   'Current Description': 'light rain'},
#  {'City': 'Abu Samrah',
#   'Country': 'SY',
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Max Temp': 22.35,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 6.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Jimenez',
#   'Country': 'MX',
#   'Lat': 28.3333,
#   'Lng': -105.4,
#   'Max Temp': 28.71,
#   'Humidity': 35,
#   'Cloudiness': 73,
#   'Wind Speed': 4.38,
#   'Current Description': 'broken clouds'},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 16.23,
#   'Humidity': 43,
#   'Cloudiness': 96,
#   'Wind Speed': 6.37,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sinnamary',
#   'Country': 'GF',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 26.05,
#   'Humidity': 80,
#   'Cloudiness': 30,
#   'Wind Speed': 5.49,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 10.45,
#   'Humidity': 73,
#   'Cloudiness': 57,
#   'Wind Speed': 10.85,
#   'Current Description': 'broken clouds'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 28.22,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 4.15,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Hardy',
#   'Country': 'CA',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 19.1,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Current Description': 'broken clouds'},
#  {'City': 'Safaga',
#   'Country': 'EG',
#   'Lat': 26.7292,
#   'Lng': 33.9365,
#   'Max Temp': 30.15,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 7.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Milkovo',
#   'Country': 'RU',
#   'Lat': 54.7167,
#   'Lng': 158.6167,
#   'Max Temp': 22.02,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barreiras',
#   'Country': 'BR',
#   'Lat': -12.1528,
#   'Lng': -44.99,
#   'Max Temp': 26.34,
#   'Humidity': 40,
#   'Cloudiness': 95,
#   'Wind Speed': 4.81,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Baquerizo Moreno',
#   'Country': 'EC',
#   'Lat': -0.9,
#   'Lng': -89.6,
#   'Max Temp': 20.57,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sitka',
#   'Country': 'US',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 15.94,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Inverell',
#   'Country': 'AU',
#   'Lat': -29.7833,
#   'Lng': 151.1167,
#   'Max Temp': 14.81,
#   'Humidity': 52,
#   'Cloudiness': 8,
#   'Wind Speed': 5.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 23.03,
#   'Humidity': 39,
#   'Cloudiness': 35,
#   'Wind Speed': 2.32,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 4.92,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 5.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 23.47,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 4.58,
#   'Current Description': 'light rain'},
#  {'City': 'Kenai',
#   'Country': 'US',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 16.68,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tura',
#   'Country': 'IN',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 24.33,
#   'Humidity': 91,
#   'Cloudiness': 94,
#   'Wind Speed': 2.79,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kosa',
#   'Country': 'RU',
#   'Lat': 59.9445,
#   'Lng': 54.9977,
#   'Max Temp': 11.65,
#   'Humidity': 68,
#   'Cloudiness': 93,
#   'Wind Speed': 1.79,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 5.91,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 16.03,
#   'Humidity': 85,
#   'Cloudiness': 1,
#   'Wind Speed': 2.52,
#   'Current Description': 'clear sky'},
#  {'City': 'Nalut',
#   'Country': 'LY',
#   'Lat': 30.3333,
#   'Lng': 10.85,
#   'Max Temp': 25.56,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Fethiye',
#   'Country': 'TR',
#   'Lat': 36.6217,
#   'Lng': 29.1164,
#   'Max Temp': 23.93,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 1.25,
#   'Current Description': 'clear sky'},
#  {'City': 'Gizo',
#   'Country': 'SB',
#   'Lat': -8.103,
#   'Lng': 156.8419,
#   'Max Temp': 29.14,
#   'Humidity': 66,
#   'Cloudiness': 37,
#   'Wind Speed': 2.79,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 13.43,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tessalit',
#   'Country': 'ML',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 32.56,
#   'Humidity': 29,
#   'Cloudiness': 82,
#   'Wind Speed': 3.63,
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Hawkesbury',
#   'Country': 'CA',
#   'Lat': 45.6169,
#   'Lng': -61.3485,
#   'Max Temp': 20.33,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Current Description': 'mist'},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 13.03,
#   'Humidity': 78,
#   'Cloudiness': 43,
#   'Wind Speed': 5.34,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vesoul',
#   'Country': 'FR',
#   'Lat': 47.5833,
#   'Lng': 5.8333,
#   'Max Temp': 16.45,
#   'Humidity': 59,
#   'Cloudiness': 83,
#   'Wind Speed': 1.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Salinopolis',
#   'Country': 'BR',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 25.66,
#   'Humidity': 84,
#   'Cloudiness': 96,
#   'Wind Speed': 5.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Okhotsk',
#   'Country': 'RU',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 15.48,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.54,
#   'Current Description': 'moderate rain'},
#  {'City': 'Port Blair',
#   'Country': 'IN',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 28.12,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 6.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 11.29,
#   'Humidity': 74,
#   'Cloudiness': 5,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 10,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 7.72,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mackay',
#   'Country': 'AU',
#   'Lat': -21.15,
#   'Lng': 149.2,
#   'Max Temp': 25.93,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 4.07,
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Pierre',
#   'Country': 'RE',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 18.28,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 2.57,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Aripuana',
#   'Country': 'BR',
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp': 25.26,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 0.35,
#   'Current Description': 'clear sky'},
#  {'City': 'Pacific Grove',
#   'Country': 'US',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 23.78,
#   'Humidity': 80,
#   'Cloudiness': 34,
#   'Wind Speed': 2.24,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 30.71,
#   'Humidity': 80,
#   'Cloudiness': 54,
#   'Wind Speed': 2.24,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint-Georges',
#   'Country': 'GD',
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp': 27.07,
#   'Humidity': 81,
#   'Cloudiness': 64,
#   'Wind Speed': 3.46,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dakar',
#   'Country': 'SN',
#   'Lat': 14.6937,
#   'Lng': -17.4441,
#   'Max Temp': 27.49,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 9.43,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ostrovnoy',
#   'Country': 'RU',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 9.97,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 6.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 28.61,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 4.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sumenep',
#   'Country': 'ID',
#   'Lat': -7.0167,
#   'Lng': 113.8667,
#   'Max Temp': 28.51,
#   'Humidity': 73,
#   'Cloudiness': 92,
#   'Wind Speed': 5.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zeya',
#   'Country': 'RU',
#   'Lat': 53.75,
#   'Lng': 127.2667,
#   'Max Temp': 19.34,
#   'Humidity': 81,
#   'Cloudiness': 25,
#   'Wind Speed': 1.45,
#   'Current Description': 'light rain'},
#  {'City': 'Sibolga',
#   'Country': 'ID',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 23.97,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yumen',
#   'Country': 'CN',
#   'Lat': 40.2833,
#   'Lng': 97.2,
#   'Max Temp': 22.54,
#   'Humidity': 27,
#   'Cloudiness': 100,
#   'Wind Speed': 4.32,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Onalaska',
#   'Country': 'US',
#   'Lat': 43.8844,
#   'Lng': -91.2351,
#   'Max Temp': 19.62,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Miri',
#   'Country': 'MY',
#   'Lat': 4.4148,
#   'Lng': 114.0089,
#   'Max Temp': 27.91,
#   'Humidity': 76,
#   'Cloudiness': 96,
#   'Wind Speed': 2.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mayo',
#   'Country': 'US',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 22.99,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Lichtenburg',
#   'Country': 'ZA',
#   'Lat': -26.152,
#   'Lng': 26.1597,
#   'Max Temp': 7.82,
#   'Humidity': 52,
#   'Cloudiness': 52,
#   'Wind Speed': 3.63,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dalgopol',
#   'Country': 'BG',
#   'Lat': 43.05,
#   'Lng': 27.35,
#   'Max Temp': 21.17,
#   'Humidity': 85,
#   'Cloudiness': 9,
#   'Wind Speed': 2.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Bela',
#   'Country': 'IN',
#   'Lat': 25.9333,
#   'Lng': 81.9833,
#   'Max Temp': 28.84,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 5.7,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 32.2,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 1.79,
#   'Current Description': 'clear sky'},
#  {'City': 'Khorixas',
#   'Country': 'NA',
#   'Lat': -20.3667,
#   'Lng': 14.9667,
#   'Max Temp': 11.02,
#   'Humidity': 61,
#   'Cloudiness': 5,
#   'Wind Speed': 2.23,
#   'Current Description': 'clear sky'},
#  {'City': 'Acapulco',
#   'Country': 'MX',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 27.9,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 1.03,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Real',
#   'Country': 'PH',
#   'Lat': 14.6625,
#   'Lng': 121.6047,
#   'Max Temp': 30.09,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 1.67,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 2.61,
#   'Humidity': 76,
#   'Cloudiness': 61,
#   'Wind Speed': 2.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Devils Lake',
#   'Country': 'US',
#   'Lat': 48.1128,
#   'Lng': -98.8651,
#   'Max Temp': 22.75,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Current Description': 'clear sky'},
#  {'City': 'San Quintin',
#   'Country': 'MX',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 22.6,
#   'Humidity': 81,
#   'Cloudiness': 77,
#   'Wind Speed': 4.92,
#   'Current Description': 'broken clouds'},
#  {'City': 'Orlik',
#   'Country': 'RU',
#   'Lat': 52.5178,
#   'Lng': 99.825,
#   'Max Temp': 13.8,
#   'Humidity': 78,
#   'Cloudiness': 97,
#   'Wind Speed': 1.77,
#   'Current Description': 'light rain'},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 25.48,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 8.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 30.9,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tharad',
#   'Country': 'IN',
#   'Lat': 24.3961,
#   'Lng': 71.6267,
#   'Max Temp': 26.79,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Krasnomayskiy',
#   'Country': 'RU',
#   'Lat': 57.6194,
#   'Lng': 34.4099,
#   'Max Temp': 14.39,
#   'Humidity': 86,
#   'Cloudiness': 16,
#   'Wind Speed': 0.55,
#   'Current Description': 'few clouds'},
#  {'City': 'Hay River',
#   'Country': 'CA',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': 19.63,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 3.39,
#   'Current Description': 'clear sky'},
#  {'City': 'Bossangoa',
#   'Country': 'CF',
#   'Lat': 6.4926,
#   'Lng': 17.4552,
#   'Max Temp': 20.89,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.44,
#   'Current Description': 'light rain'},
#  {'City': 'Tomohon',
#   'Country': 'ID',
#   'Lat': 1.3346,
#   'Lng': 124.8392,
#   'Max Temp': 27.52,
#   'Humidity': 64,
#   'Cloudiness': 98,
#   'Wind Speed': 1.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lakes Entrance',
#   'Country': 'AU',
#   'Lat': -37.8811,
#   'Lng': 147.981,
#   'Max Temp': 11.76,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 7.75,
#   'Current Description': 'light rain'},
#  {'City': 'Viedma',
#   'Country': 'AR',
#   'Lat': -40.8135,
#   'Lng': -62.9967,
#   'Max Temp': 14.74,
#   'Humidity': 42,
#   'Cloudiness': 9,
#   'Wind Speed': 7.54,
#   'Current Description': 'clear sky'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 20.14,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 7.2,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yeniseysk',
#   'Country': 'RU',
#   'Lat': 58.4497,
#   'Lng': 92.1703,
#   'Max Temp': 15.3,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 2.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 10.01,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 7.72,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Phalaborwa',
#   'Country': 'ZA',
#   'Lat': -23.943,
#   'Lng': 31.1411,
#   'Max Temp': 17.95,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 2.23,
#   'Current Description': 'clear sky'},
#  {'City': 'Alsfeld',
#   'Country': 'DE',
#   'Lat': 50.75,
#   'Lng': 9.2667,
#   'Max Temp': 16.93,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 1.58,
#   'Current Description': 'clear sky'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 20.16,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 7.2,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hrymayliv',
#   'Country': 'UA',
#   'Lat': 49.3321,
#   'Lng': 26.0111,
#   'Max Temp': 15.98,
#   'Humidity': 93,
#   'Cloudiness': 56,
#   'Wind Speed': 1.79,
#   'Current Description': 'broken clouds'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 15.98,
#   'Humidity': 96,
#   'Cloudiness': 59,
#   'Wind Speed': 2.68,
#   'Current Description': 'broken clouds'},
#  {'City': 'Muyezerskiy',
#   'Country': 'RU',
#   'Lat': 63.9333,
#   'Lng': 31.65,
#   'Max Temp': 12.77,
#   'Humidity': 67,
#   'Cloudiness': 97,
#   'Wind Speed': 2.67,
#   'Current Description': 'light rain'},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 11.81,
#   'Humidity': 43,
#   'Cloudiness': 88,
#   'Wind Speed': 14.04,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Trat',
#   'Country': 'TH',
#   'Lat': 12.5,
#   'Lng': 102.5,
#   'Max Temp': 29.37,
#   'Humidity': 80,
#   'Cloudiness': 47,
#   'Wind Speed': 0.75,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Stornoway',
#   'Country': 'GB',
#   'Lat': 58.2093,
#   'Lng': -6.3865,
#   'Max Temp': 12.98,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.03,
#   'Current Description': 'fog'},
#  {'City': 'Mayumba',
#   'Country': 'GA',
#   'Lat': -3.432,
#   'Lng': 10.6554,
#   'Max Temp': 21.55,
#   'Humidity': 82,
#   'Cloudiness': 93,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ukiah',
#   'Country': 'US',
#   'Lat': 39.1502,
#   'Lng': -123.2078,
#   'Max Temp': 32.14,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Current Description': 'clear sky'},
#  {'City': 'Kharitonovo',
#   'Country': 'RU',
#   'Lat': 61.4009,
#   'Lng': 47.4978,
#   'Max Temp': 10.04,
#   'Humidity': 78,
#   'Cloudiness': 45,
#   'Wind Speed': 1.33,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Srednekolymsk',
#   'Country': 'RU',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': 5.19,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 7.11,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bastrop',
#   'Country': 'US',
#   'Lat': 32.7562,
#   'Lng': -91.8724,
#   'Max Temp': 27.68,
#   'Humidity': 87,
#   'Cloudiness': 27,
#   'Wind Speed': 1.84,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 11.56,
#   'Humidity': 78,
#   'Cloudiness': 76,
#   'Wind Speed': 8.91,
#   'Current Description': 'light rain'},
#  {'City': 'Mehamn',
#   'Country': 'NO',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 9.97,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 4.12,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Antalaha',
#   'Country': 'MG',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 19.56,
#   'Humidity': 89,
#   'Cloudiness': 82,
#   'Wind Speed': 2.63,
#   'Current Description': 'light rain'},
#  {'City': 'Roswell',
#   'Country': 'US',
#   'Lat': 34.0232,
#   'Lng': -84.3616,
#   'Max Temp': 24.92,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Current Description': 'clear sky'},
#  {'City': 'Muzhi',
#   'Country': 'RU',
#   'Lat': 65.3667,
#   'Lng': 64.6667,
#   'Max Temp': 9.01,
#   'Humidity': 69,
#   'Cloudiness': 99,
#   'Wind Speed': 8.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bria',
#   'Country': 'CF',
#   'Lat': 6.5423,
#   'Lng': 21.9863,
#   'Max Temp': 20.56,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.01,
#   'Current Description': 'light rain'},
#  {'City': 'Oktyabrskoye',
#   'Country': 'RU',
#   'Lat': 43.0645,
#   'Lng': 44.7417,
#   'Max Temp': 16.08,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 2,
#   'Current Description': 'clear sky'},
#  {'City': 'California City',
#   'Country': 'US',
#   'Lat': 35.1258,
#   'Lng': -117.9859,
#   'Max Temp': 37.14,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 8.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Broome',
#   'Country': 'US',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 16.5,
#   'Humidity': 77,
#   'Cloudiness': 8,
#   'Wind Speed': 0.78,
#   'Current Description': 'clear sky'},
#  {'City': 'Saquena',
#   'Country': 'PE',
#   'Lat': -4.6667,
#   'Lng': -73.5167,
#   'Max Temp': 24.01,
#   'Humidity': 72,
#   'Cloudiness': 4,
#   'Wind Speed': 0.38,
#   'Current Description': 'clear sky'},
#  {'City': 'San Policarpo',
#   'Country': 'PH',
#   'Lat': 12.1791,
#   'Lng': 125.5072,
#   'Max Temp': 28.61,
#   'Humidity': 76,
#   'Cloudiness': 70,
#   'Wind Speed': 3.4,
#   'Current Description': 'moderate rain'},
#  {'City': 'Chuguyevka',
#   'Country': 'RU',
#   'Lat': 44.1653,
#   'Lng': 133.8633,
#   'Max Temp': 22.67,
#   'Humidity': 71,
#   'Cloudiness': 33,
#   'Wind Speed': 2.31,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Alofi',
#   'Country': 'NU',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 23.06,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 9.49,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Collie',
#   'Country': 'AU',
#   'Lat': -33.3667,
#   'Lng': 116.15,
#   'Max Temp': 12.94,
#   'Humidity': 67,
#   'Cloudiness': 33,
#   'Wind Speed': 0.75,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 27.52,
#   'Humidity': 78,
#   'Cloudiness': 53,
#   'Wind Speed': 7.35,
#   'Current Description': 'light rain'},
#  {'City': 'Calvia',
#   'Country': 'ES',
#   'Lat': 39.5657,
#   'Lng': 2.5062,
#   'Max Temp': 33.26,
#   'Humidity': 57,
#   'Cloudiness': 56,
#   'Wind Speed': 4.42,
#   'Current Description': 'broken clouds'},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 13.21,
#   'Humidity': 83,
#   'Cloudiness': 45,
#   'Wind Speed': 9.12,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kununurra',
#   'Country': 'AU',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 29.99,
#   'Humidity': 21,
#   'Cloudiness': 6,
#   'Wind Speed': 5.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Dingle',
#   'Country': 'PH',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 29.14,
#   'Humidity': 76,
#   'Cloudiness': 51,
#   'Wind Speed': 3.17,
#   'Current Description': 'light rain'},
#  {'City': 'Brumado',
#   'Country': 'BR',
#   'Lat': -14.2036,
#   'Lng': -41.6653,
#   'Max Temp': 20,
#   'Humidity': 69,
#   'Cloudiness': 61,
#   'Wind Speed': 2.94,
#   'Current Description': 'broken clouds'},
#  {'City': 'Awjilah',
#   'Country': 'LY',
#   'Lat': 29.1081,
#   'Lng': 21.2869,
#   'Max Temp': 25.12,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 4.89,
#   'Current Description': 'clear sky'},
#  {'City': 'Skjervoy',
#   'Country': 'NO',
#   'Lat': 70.0311,
#   'Lng': 20.9714,
#   'Max Temp': 12,
#   'Humidity': 75,
#   'Cloudiness': 88,
#   'Wind Speed': 15.54,
#   'Current Description': 'light rain'},
#  {'City': 'Launceston',
#   'Country': 'AU',
#   'Lat': -41.45,
# ...
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 11.59,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 3.35,
#   'Current Description': 'clear sky'},
#  {'City': 'Isangel',
#   'Country': 'VU',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 24.32,
#   'Humidity': 73,
#   'Cloudiness': 46,
#   'Wind Speed': 7.96,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Balykshi',
#   'Country': 'KZ',
#   'Lat': 47.0667,
#   'Lng': 51.8667,
#   'Max Temp': 23,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 5,
#   'Current Description': 'clear sky'},
#  {'City': 'Sargatskoye',
#   'Country': 'RU',
#   'Lat': 55.6101,
#   'Lng': 73.4972,
#   'Max Temp': 13.27,
#   'Humidity': 83,
#   'Cloudiness': 73,
#   'Wind Speed': 7.35,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sarangani',
#   'Country': 'PH',
#   'Lat': 5.4033,
#   'Lng': 125.4636,
#   'Max Temp': 28.58,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 2.9,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Artigas',
#   'Country': 'UY',
#   'Lat': -30.4,
#   'Lng': -56.4667,
#   'Max Temp': 14.98,
#   'Humidity': 92,
#   'Cloudiness': 0,
#   'Wind Speed': 3.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Minab',
#   'Country': 'IR',
#   'Lat': 27.1467,
#   'Lng': 57.0801,
#   'Max Temp': 30.18,
#   'Humidity': 70,
#   'Cloudiness': 67,
#   'Wind Speed': 0,
#   'Current Description': 'haze'},
#  {'City': 'Voh',
#   'Country': 'NC',
#   'Lat': -20.9667,
#   'Lng': 164.7,
#   'Max Temp': 26.65,
#   'Humidity': 53,
#   'Cloudiness': 98,
#   'Wind Speed': 4.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nhamunda',
#   'Country': 'BR',
#   'Lat': -2.1861,
#   'Lng': -56.7131,
#   'Max Temp': 25.73,
#   'Humidity': 61,
#   'Cloudiness': 48,
#   'Wind Speed': 0.88,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Fundacion',
#   'Country': 'CO',
#   'Lat': 10.5207,
#   'Lng': -74.185,
#   'Max Temp': 24.17,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 0.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Burnie',
#   'Country': 'AU',
#   'Lat': -41.0667,
#   'Lng': 145.9167,
#   'Max Temp': 15.26,
#   'Humidity': 65,
#   'Cloudiness': 58,
#   'Wind Speed': 4.16,
#   'Current Description': 'broken clouds'},
#  {'City': 'Setermoen',
#   'Country': 'NO',
#   'Lat': 68.861,
#   'Lng': 18.3486,
#   'Max Temp': 10.98,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 0.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jieshi',
#   'Country': 'CN',
#   'Lat': 22.8134,
#   'Lng': 115.8257,
#   'Max Temp': 29.26,
#   'Humidity': 74,
#   'Cloudiness': 62,
#   'Wind Speed': 1.71,
#   'Current Description': 'broken clouds'},
#  {'City': 'Grootfontein',
#   'Country': 'NA',
#   'Lat': -19.5667,
#   'Lng': 18.1167,
#   'Max Temp': 11.76,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Current Description': 'clear sky'},
#  {'City': 'Venice',
#   'Country': 'US',
#   'Lat': 27.0998,
#   'Lng': -82.4543,
#   'Max Temp': 29.01,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Current Description': 'clear sky'},
#  {'City': 'Bourail',
#   'Country': 'NC',
#   'Lat': -21.5667,
#   'Lng': 165.4833,
#   'Max Temp': 24.59,
#   'Humidity': 60,
#   'Cloudiness': 95,
#   'Wind Speed': 4.78,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Iracoubo',
#   'Country': 'GF',
#   'Lat': 5.4802,
#   'Lng': -53.2011,
#   'Max Temp': 26.03,
#   'Humidity': 79,
#   'Cloudiness': 42,
#   'Wind Speed': 5.85,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Taltal',
#   'Country': 'CL',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 14.13,
#   'Humidity': 78,
#   'Cloudiness': 7,
#   'Wind Speed': 1,
#   'Current Description': 'clear sky'},
#  {'City': 'Manoel Urbano',
#   'Country': 'BR',
#   'Lat': -8.8389,
#   'Lng': -69.2597,
#   'Max Temp': 25.89,
#   'Humidity': 57,
#   'Cloudiness': 79,
#   'Wind Speed': 0.51,
#   'Current Description': 'broken clouds'},
#  {'City': 'La Ronge',
#   'Country': 'CA',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 22.14,
#   'Humidity': 53,
#   'Cloudiness': 20,
#   'Wind Speed': 2.57,
#   'Current Description': 'few clouds'},
#  {'City': 'Novaya Igirma',
#   'Country': 'RU',
#   'Lat': 57.1334,
#   'Lng': 103.9112,
#   'Max Temp': 16.05,
#   'Humidity': 52,
#   'Cloudiness': 8,
#   'Wind Speed': 1.38,
#   'Current Description': 'clear sky'},
#  {'City': 'Horn',
#   'Country': 'DE',
#   'Lat': 51.8715,
#   'Lng': 8.9451,
#   'Max Temp': 19.86,
#   'Humidity': 77,
#   'Cloudiness': 10,
#   'Wind Speed': 1.84,
#   'Current Description': 'clear sky'},
#  {'City': 'Mirabad',
#   'Country': 'AF',
#   'Lat': 30.4362,
#   'Lng': 61.8383,
#   'Max Temp': 28.95,
#   'Humidity': 19,
#   'Cloudiness': 15,
#   'Wind Speed': 10.82,
#   'Current Description': 'few clouds'},
#  {'City': 'Khilok',
#   'Country': 'RU',
#   'Lat': 51.3674,
#   'Lng': 110.4676,
#   'Max Temp': 21.47,
#   'Humidity': 42,
#   'Cloudiness': 11,
#   'Wind Speed': 1.64,
#   'Current Description': 'few clouds'},
#  {'City': 'Hervey Bay',
#   'Country': 'AU',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 18.64,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 1.53,
#   'Current Description': 'clear sky'},
#  {'City': 'Beaverlodge',
#   'Country': 'CA',
#   'Lat': 55.2166,
#   'Lng': -119.4361,
#   'Max Temp': 14.64,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 4.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Marsh Harbour',
#   'Country': 'BS',
#   'Lat': 26.5412,
#   'Lng': -77.0636,
#   'Max Temp': 28.1,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 1,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ocampo',
#   'Country': 'MX',
#   'Lat': 21.65,
#   'Lng': -101.5,
#   'Max Temp': 14.74,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dauphin',
#   'Country': 'CA',
#   'Lat': 51.1494,
#   'Lng': -100.0502,
#   'Max Temp': 21.08,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Current Description': 'clear sky'},
#  {'City': 'Megion',
#   'Country': 'RU',
#   'Lat': 61.0296,
#   'Lng': 76.1136,
#   'Max Temp': 12.01,
#   'Humidity': 82,
#   'Cloudiness': 97,
#   'Wind Speed': 8.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cuamba',
#   'Country': 'MZ',
#   'Lat': -14.8031,
#   'Lng': 36.5372,
#   'Max Temp': 16.63,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 2.02,
#   'Current Description': 'clear sky'},
#  {'City': 'Tiarei',
#   'Country': 'PF',
#   'Lat': -17.5333,
#   'Lng': -149.3333,
#   'Max Temp': 28.01,
#   'Humidity': 76,
#   'Cloudiness': 63,
#   'Wind Speed': 6.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'Leninskoye',
#   'Country': 'KZ',
#   'Lat': 41.7589,
#   'Lng': 69.3864,
#   'Max Temp': 26.19,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 1.49,
#   'Current Description': 'clear sky'},
#  {'City': 'Maniitsoq',
#   'Country': 'GL',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 6.46,
#   'Humidity': 79,
#   'Cloudiness': 89,
#   'Wind Speed': 4.64,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ust-Nera',
#   'Country': 'RU',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': 21.91,
#   'Humidity': 44,
#   'Cloudiness': 59,
#   'Wind Speed': 2.21,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dumbravita',
#   'Country': 'RO',
#   'Lat': 45.7667,
#   'Lng': 25.4333,
#   'Max Temp': 16.77,
#   'Humidity': 82,
#   'Cloudiness': 76,
#   'Wind Speed': 0.59,
#   'Current Description': 'broken clouds'},
#  {'City': 'Teknaf',
#   'Country': 'BD',
#   'Lat': 20.8624,
#   'Lng': 92.3058,
#   'Max Temp': 25.2,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.49,
#   'Current Description': 'moderate rain'},
#  {'City': 'Ugoofaaru',
#   'Country': 'MV',
#   'Lat': 5.6667,
#   'Lng': 73,
#   'Max Temp': 27.36,
#   'Humidity': 77,
#   'Cloudiness': 96,
#   'Wind Speed': 3.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Karaton',
#   'Country': 'ID',
#   'Lat': -6.3424,
#   'Lng': 106.1045,
#   'Max Temp': 27.84,
#   'Humidity': 73,
#   'Cloudiness': 96,
#   'Wind Speed': 0.39,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Malumfashi',
#   'Country': 'NG',
#   'Lat': 11.7853,
#   'Lng': 7.6218,
#   'Max Temp': 21.11,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.31,
#   'Current Description': 'moderate rain'},
#  {'City': 'Port-Gentil',
#   'Country': 'GA',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 23.46,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 6.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Wilches',
#   'Country': 'CO',
#   'Lat': 7.3483,
#   'Lng': -73.896,
#   'Max Temp': 23.87,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 0.64,
#   'Current Description': 'broken clouds'},
#  {'City': 'Puerto Colombia',
#   'Country': 'CO',
#   'Lat': 10.9878,
#   'Lng': -74.9547,
#   'Max Temp': 28.05,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 2.69,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cravo Norte',
#   'Country': 'CO',
#   'Lat': 6.3017,
#   'Lng': -70.2041,
#   'Max Temp': 24.53,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 1.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Miles City',
#   'Country': 'US',
#   'Lat': 46.4083,
#   'Lng': -105.8406,
#   'Max Temp': 32.54,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Current Description': 'clear sky'},
#  {'City': 'Tartagal',
#   'Country': 'AR',
#   'Lat': -22.5164,
#   'Lng': -63.8013,
#   'Max Temp': 18.23,
#   'Humidity': 52,
#   'Cloudiness': 7,
#   'Wind Speed': 1.59,
#   'Current Description': 'clear sky'},
#  {'City': 'Palana',
#   'Country': 'RU',
#   'Lat': 59.1167,
#   'Lng': 159.9667,
#   'Max Temp': 12.83,
#   'Humidity': 87,
#   'Cloudiness': 89,
#   'Wind Speed': 4.67,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shellbrook',
#   'Country': 'CA',
#   'Lat': 53.2168,
#   'Lng': -106.4011,
#   'Max Temp': 17.57,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 6.48,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mikuni',
#   'Country': 'JP',
#   'Lat': 36.2171,
#   'Lng': 136.1519,
#   'Max Temp': 27.95,
#   'Humidity': 83,
#   'Cloudiness': 80,
#   'Wind Speed': 5.16,
#   'Current Description': 'light rain'},
#  {'City': 'Santiago Del Estero',
#   'Country': 'AR',
#   'Lat': -27.7951,
#   'Lng': -64.2615,
#   'Max Temp': 20.09,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 4.19,
#   'Current Description': 'clear sky'},
#  {'City': 'Karachi',
#   'Country': 'PK',
#   'Lat': 24.9056,
#   'Lng': 67.0822,
#   'Max Temp': 25.9,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 2.57,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Balkanabat',
#   'Country': 'TM',
#   'Lat': 39.5108,
#   'Lng': 54.3671,
#   'Max Temp': 30.15,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 4.6,
#   'Current Description': 'clear sky'},
#  {'City': 'Chillan',
#   'Country': 'CL',
#   'Lat': -36.6066,
#   'Lng': -72.1034,
#   'Max Temp': 11.18,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 5.14,
#   'Current Description': 'few clouds'},
#  {'City': 'Katete',
#   'Country': 'UG',
#   'Lat': -0.7818,
#   'Lng': 29.7544,
#   'Max Temp': 17.24,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 1.03,
#   'Current Description': 'light rain'},
#  {'City': 'Road Town',
#   'Country': 'VG',
#   'Lat': 18.4167,
#   'Lng': -64.6167,
#   'Max Temp': 29.05,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 5.14,
#   'Current Description': 'few clouds'},
#  {'City': 'Phayao',
#   'Country': 'TH',
#   'Lat': 19.25,
#   'Lng': 100.25,
#   'Max Temp': 25.2,
#   'Humidity': 87,
#   'Cloudiness': 97,
#   'Wind Speed': 0.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mission Bend',
#   'Country': 'US',
#   'Lat': 29.6938,
#   'Lng': -95.6649,
#   'Max Temp': 29.5,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Current Description': 'clear sky'},
#  {'City': 'Matara',
#   'Country': 'LK',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 26.67,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 4.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hami',
#   'Country': 'CN',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 28.42,
#   'Humidity': 20,
#   'Cloudiness': 13,
#   'Wind Speed': 4.89,
#   'Current Description': 'few clouds'},
#  {'City': 'Tyshkivka',
#   'Country': 'UA',
#   'Lat': 48.4967,
#   'Lng': 30.9423,
#   'Max Temp': 19.74,
#   'Humidity': 52,
#   'Cloudiness': 100,
#   'Wind Speed': 3.78,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mareeba',
#   'Country': 'AU',
#   'Lat': -17,
#   'Lng': 145.4333,
#   'Max Temp': 26.91,
#   'Humidity': 58,
#   'Cloudiness': 53,
#   'Wind Speed': 1.51,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kalaleh',
#   'Country': 'IR',
#   'Lat': 37.3807,
#   'Lng': 55.4916,
#   'Max Temp': 22.78,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Agadez',
#   'Country': 'NE',
#   'Lat': 19.75,
#   'Lng': 10.25,
#   'Max Temp': 30.3,
#   'Humidity': 15,
#   'Cloudiness': 25,
#   'Wind Speed': 4.31,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Micheweni',
#   'Country': 'TZ',
#   'Lat': -4.9667,
#   'Lng': 39.8333,
#   'Max Temp': 23.7,
#   'Humidity': 81,
#   'Cloudiness': 6,
#   'Wind Speed': 6.34,
#   'Current Description': 'clear sky'},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 33.01,
#   'Humidity': 56,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Miguel Hidalgo',
#   'Country': 'MX',
#   'Lat': 19.4225,
#   'Lng': -99.2028,
#   'Max Temp': 17.67,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Current Description': 'broken clouds'},
#  {'City': 'Langxiang',
#   'Country': 'CN',
#   'Lat': 46.95,
#   'Lng': 128.8833,
#   'Max Temp': 23.42,
#   'Humidity': 54,
#   'Cloudiness': 18,
#   'Wind Speed': 1.18,
#   'Current Description': 'few clouds'},
#  {'City': 'Prado',
#   'Country': 'BR',
#   'Lat': -17.3411,
#   'Lng': -39.2208,
#   'Max Temp': 19.85,
#   'Humidity': 70,
#   'Cloudiness': 68,
#   'Wind Speed': 3.17,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bukama',
#   'Country': 'CD',
#   'Lat': -9.2,
#   'Lng': 25.85,
#   'Max Temp': 19.97,
#   'Humidity': 41,
#   'Cloudiness': 7,
#   'Wind Speed': 1.67,
#   'Current Description': 'clear sky'},
#  {'City': 'San-Pedro',
#   'Country': 'CI',
#   'Lat': 4.7485,
#   'Lng': -6.6363,
#   'Max Temp': 23.22,
#   'Humidity': 89,
#   'Cloudiness': 93,
#   'Wind Speed': 2.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sovetskaya Gavan',
#   'Country': 'RU',
#   'Lat': 48.9723,
#   'Lng': 140.2878,
#   'Max Temp': 20.91,
#   'Humidity': 64,
#   'Cloudiness': 30,
#   'Wind Speed': 3.18,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Te Anau',
#   'Country': 'NZ',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 10.63,
#   'Humidity': 57,
#   'Cloudiness': 11,
#   'Wind Speed': 1.66,
#   'Current Description': 'few clouds'},
#  {'City': 'Kupang',
#   'Country': 'ID',
#   'Lat': -10.1667,
#   'Lng': 123.5833,
#   'Max Temp': 30.19,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 3.03,
#   'Current Description': 'clear sky'},
#  {'City': 'Zhicheng',
#   'Country': 'CN',
#   'Lat': 30.2956,
#   'Lng': 111.5047,
#   'Max Temp': 34.06,
#   'Humidity': 55,
#   'Cloudiness': 53,
#   'Wind Speed': 2.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Morant Bay',
#   'Country': 'JM',
#   'Lat': 17.8815,
#   'Lng': -76.4093,
#   'Max Temp': 28.79,
#   'Humidity': 85,
#   'Cloudiness': 52,
#   'Wind Speed': 2.38,
#   'Current Description': 'broken clouds'},
#  {'City': 'Uribia',
#   'Country': 'CO',
#   'Lat': 11.7139,
#   'Lng': -72.266,
#   'Max Temp': 28.3,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 6.96,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Stryn',
#   'Country': 'NO',
#   'Lat': 61.9045,
#   'Lng': 6.7226,
#   'Max Temp': 16.19,
#   'Humidity': 86,
#   'Cloudiness': 96,
#   'Wind Speed': 1.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lomas De Sargentillo',
#   'Country': 'EC',
#   'Lat': -1.8833,
#   'Lng': -80.0833,
#   'Max Temp': 23.92,
#   'Humidity': 83,
#   'Cloudiness': 13,
#   'Wind Speed': 2.83,
#   'Current Description': 'few clouds'},
#  {'City': 'Qaracala',
#   'Country': 'AZ',
#   'Lat': 39.8132,
#   'Lng': 48.9523,
#   'Max Temp': 23.71,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 0.34,
#   'Current Description': 'clear sky'},
#  {'City': 'Basirhat',
#   'Country': 'IN',
#   'Lat': 22.6685,
#   'Lng': 88.8697,
#   'Max Temp': 27.99,
#   'Humidity': 89,
#   'Cloudiness': 89,
#   'Wind Speed': 8.44,
#   'Current Description': 'light rain'}]

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Santona      ES  43.4439   -3.4576     22.17        90
# 1               Hithadhoo      MV  -0.6000   73.0833     27.80        71
# 2          Chernyshevskiy      RU  63.0128  112.4714      8.94        84
# 3                  Tadine      NC -21.5500  167.8833     23.47        67
# 4       Praxedis Guerrero      MX  31.3667 -106.0167     31.72        26
# ..                    ...     ...      ...       ...       ...       ...
# 703                Uribia      CO  11.7139  -72.2660     28.30        69
# 704                 Stryn      NO  61.9045    6.7226     16.19        86
# 705  Lomas De Sargentillo      EC  -1.8833  -80.0833     23.92        83
# 706              Qaracala      AZ  39.8132   48.9523     23.71        60
# 707              Basirhat      IN  22.6685   88.8697     27.99        89
#
#      Cloudiness  Wind Speed Current Description
# 0           100        3.85     overcast clouds
# 1            76        1.18       broken clouds
# 2           100        2.62     overcast clouds
# 3           100        8.18     overcast clouds
# 4            44        1.13    scattered clouds
# ..          ...         ...                 ...
# 703         100        6.96     overcast clouds
# 704          96        1.62     overcast clouds
# 705          13        2.83          few clouds
# 706           0        0.34           clear sky
# 707          89        8.44          light rain
#
# [708 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
